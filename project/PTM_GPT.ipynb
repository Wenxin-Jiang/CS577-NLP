# %%
# !module load anaconda/2020.11-py38
# !module load cuda/11.7.0
# !module load gcc/6.3.0

# %%
import re
import os
from tqdm import tqdm
import openai
import json

from loguru import logger

# %%
def remove_code_snippets(text):
    return re.sub(r'```.*?```', '', text, flags=re.DOTALL)


def remove_tables(text):
    def replace_table(match):
        header = re.findall(r'\|([^|\n]+)\|', match.group(0))
        values = re.findall(r'\|([^|\n]+)\|', match.group(0)[match.end(1):])
        return "\n".join(header + values)

    return re.sub(r'(\|.*\|\n\|:?-+:?\|.*\n)((\|.*\|(\n)?)+)', replace_table, text, flags=re.MULTILINE)


def remove_urls(text):
    return re.sub(r'http[s]?://(?:[a-zA-Z]|[0-9]|[$-_@.&+]|[!*\\(\\),]|(?:%[0-9a-fA-F][0-9a-fA-F]))+', '', text)


def parse_readme(readme):
    main_text = re.sub(r"---\n.+?\n---", "", readme, flags=re.DOTALL).strip()
    main_text = remove_code_snippets(main_text)
    main_text = remove_tables(main_text)
    main_text = remove_urls(main_text)
    return main_text

# %%
def read_readme_files(base_dir):
    readmes = {}
    for author_name in tqdm(os.listdir(base_dir)):
        for model_name in os.listdir(os.path.join(base_dir, author_name)):
            readme_path = os.path.join(base_dir, author_name, model_name, "README.md")
            # logger.debug(readme_path)
            if os.path.exists(readme_path):
                with open(readme_path, "r") as f:
                    readmes[model_name] = f.read()
            logger.info(f"author_name, model_name, readme_path are {author_name}, {model_name}, {readme_path}")
            break
        break
    return readmes

# %%
def extract_metadata_gpt35(prompt):
    MODEL = "gpt-3.5-turbo"
    response = openai.ChatCompletion.create(
        model = MODEL,
        messages=[
        {"role": "system", "content": "You are classifying the category and task of pre-trained model based on the given README files."},
        {"role": "user", "content": "Can you clasify the following readme file into one of the element in the dict?\n \
        Use this format, dont't generate any other texts 'task: category'" + prompt},
        ],
        temperature = 0.1,    
        max_tokens = 200,
    )
    logger.info(response)
    message = response["choices"][0]["message"]["content"].strip().lower().replace("\n", " ")

    return response.choices[0].text.strip()

def truncate_text(text, max_tokens=200):
    tokens = text.split()
    truncated_tokens = tokens[:max_tokens]
    truncated_text = ' '.join(truncated_tokens)
    return truncated_text

def extract_metadata(metadata, readme):
    readme = parse_readme(readme)
    truncated_documentation = truncate_text(readme)
    # prompt = f"Extract pre-trained deep learning model metadata for the following model documentation: \n{readme}"
    prompt = f"Here is a mapping of {{task: category}}: mapping = {{\n"
    for task in [
        'feature-extraction: multimodal',
        'text-to-image:multimodal',
        'image-to-text:multimodal',
        'text-to-video:multimodal',
        'visual-question-answering:multimodal',
        'graph-machine-learning:multimodal',
        'graph-ml:multimodal',
        'depth-estimation:computer-vision',
        'image-classification:computer-vision',
        'object-detection:computer-vision',
        'image-segmentation:computer-vision',
        'image-to-image:computer-vision',
        'unconditional-image-generation:computer-vision',
        'video-classification:computer-vision',
        'zero-shot-image-classification:computer-vision',
        'text-classification:natural-language-processing',
        'token-classification:natural-language-processing',
        'table-question-answering:natural-language-processing',
        'question-answering:natural-language-processing',
        'zero-shot-classification:natural-language-processing',
        'translation:natural-language-processing',
        'summarization:natural-language-processing',
        'conversational:natural-language-processing',
        'text-generation:natural-language-processing',
        'text2text-generation:natural-language-processing',
        'fill-mask:natural-language-processing',
        'sentence-similarity:natural-language-processing',
        'table-to-text:natural-language-processing', # dataset task
        'multiple-choice:natural-language-processing',
        'text-retrieval:natural-language-processing', # dataset task
        'document-question-answering:natural-language-processing', # model task
        'text-to-speech:audio',
        'automatic-speech-recognition:audio',
        'audio-to-audio:audio',
        'audio-classification:audio',
        'voice-activity-detection:audio',
        'tabular-classification:tabular',
        'tabular-regression:tabular',
        'tabular-to-text:tabular', # dataset task
        'time-series-forecasting:tabular', # dataset task
        'reinforcement-learning:reinforcement-learning', # model task
        'robotics:reinforcement-learning', # model task
        'null: None',
        'other: None',
        ]:
            prompt = f"{prompt} '{task}'\n"
    logger.debug(prompt)

    # prompt = f"{prompt}}}\n\n"
    prompt = f"{prompt}\n{truncated_documentation}"

    # logger.debug(prompt)
    # response = openai.Completion.create(
    #     engine="davinci",
    #     prompt=prompt,
    #     max_tokens=100,
    #     n=1,
    #     stop=None,
    #     temperature=0.5,
    # )

    prompt = f""
    metadata_text = extract_metadata_gpt35(prompt)
    logger.debug(metadata_text)
    metadata[model_name] = metadata_text

    with open("metadata.txt", "w") as file:
        for entry in metadata:
            for key, value in entry.items():
                file.write(f"{key}: {value}\n")
            file.write("\n")
    return metadata

# %%
base_dir = "/scratch/gilbreth/jiang784/PTMTorrent/huggingface/PTM-Torrent/ptm_torrent/huggingface/data/huggingface/repos"
metadata_dir = "/scratch/gilbreth/jiang784/PTMTorrent/PTMTorrent/ptm_torrent/huggingface/data/huggingface/json"
metadata_file = metadata_dir + "/huggingface.json"

# %%
with open(metadata_file, 'r') as f:
    HF_metadata = json.load(f)

# %%
HF_metadata
# Out:
# [{'id': 0,
#   'LatestGitCommitSHA': 'aeffd769076a5c4f83b2546aea99ca45a15a5da4',
#   'ModelHub': {'MetadataFilePath': 'data/huggingface/json/metadata/hf_metadata.json',
#    'MetadataObjectID': 'albert-base-v1',
#    'ModelHubName': 'Hugging Face',
#    'ModelHubURL': 'https://huggingface.co/'},
#   'ModelName': 'albert-base-v1',
#   'ModelOwner': 'http://huggingface.co/',
#   'ModelOwnerURL': 'http://huggingface.co/',
#   'ModelURL': 'https://huggingface.co/albert-base-v1',
#   'ModelArchitecture': 'albert',
#   'ModelTask': 'fill-mask'},
#  {'id': 1,
#   'LatestGitCommitSHA': '51dbd9db43a0c6eba97f74b91ce26fface509e0b',
#   'ModelHub': {'MetadataFilePath': 'data/huggingface/json/metadata/hf_metadata.json',
#    'MetadataObjectID': 'albert-base-v2',
#    'ModelHubName': 'Hugging Face',
#    'ModelHubURL': 'https://huggingface.co/'},
#   'ModelName': 'albert-base-v2',
#   'ModelOwner': 'http://huggingface.co/',
#   'ModelOwnerURL': 'http://huggingface.co/',
#   'ModelURL': 'https://huggingface.co/albert-base-v2',
#   'ModelArchitecture': 'albert',
#   'ModelTask': 'fill-mask'},
#  {'id': 2,
#   'LatestGitCommitSHA': '17aeb59edfd7c7732fb96248a95f5c271a9fa28f',
#   'ModelHub': {'MetadataFilePath': 'data/huggingface/json/metadata/hf_metadata.json',
#    'MetadataObjectID': 'albert-large-v1',
#    'ModelHubName': 'Hugging Face',
#    'ModelHubURL': 'https://huggingface.co/'},
#   'ModelName': 'albert-large-v1',
#   'ModelOwner': 'http://huggingface.co/',
#   'ModelOwnerURL': 'http://huggingface.co/',
#   'ModelURL': 'https://huggingface.co/albert-large-v1',
#   'ModelArchitecture': 'albert',
#   'ModelTask': 'fill-mask'},
#  {'id': 3,
#   'LatestGitCommitSHA': 'c76159dc6b4d18f16d303451ae64b4f34a7d0d63',
#   'ModelHub': {'MetadataFilePath': 'data/huggingface/json/metadata/hf_metadata.json',
#    'MetadataObjectID': 'albert-large-v2',
#    'ModelHubName': 'Hugging Face',
#    'ModelHubURL': 'https://huggingface.co/'},
#   'ModelName': 'albert-large-v2',
#   'ModelOwner': 'http://huggingface.co/',
#   'ModelOwnerURL': 'http://huggingface.co/',
#   'ModelURL': 'https://huggingface.co/albert-large-v2',
#   'ModelArchitecture': 'albert',
#   'ModelTask': 'fill-mask'},
#  {'id': 4,
#   'LatestGitCommitSHA': 'a74dd20bb0c3d36e36938da0b86adc5d2ec60315',
#   'ModelHub': {'MetadataFilePath': 'data/huggingface/json/metadata/hf_metadata.json',
#    'MetadataObjectID': 'albert-xlarge-v1',
#    'ModelHubName': 'Hugging Face',
#    'ModelHubURL': 'https://huggingface.co/'},
#   'ModelName': 'albert-xlarge-v1',
#   'ModelOwner': 'http://huggingface.co/',
#   'ModelOwnerURL': 'http://huggingface.co/',
#   'ModelURL': 'https://huggingface.co/albert-xlarge-v1',
#   'ModelArchitecture': 'albert',
#   'ModelTask': 'fill-mask'},
#  {'id': 5,
#   'LatestGitCommitSHA': '0ba5a4b12dff18dbb93712e5ab5ea252c09728d8',
#   'ModelHub': {'MetadataFilePath': 'data/huggingface/json/metadata/hf_metadata.json',
#    'MetadataObjectID': 'albert-xlarge-v2',
#    'ModelHubName': 'Hugging Face',
#    'ModelHubURL': 'https://huggingface.co/'},
#   'ModelName': 'albert-xlarge-v2',
#   'ModelOwner': 'http://huggingface.co/',
#   'ModelOwnerURL': 'http://huggingface.co/',
#   'ModelURL': 'https://huggingface.co/albert-xlarge-v2',
#   'ModelArchitecture': 'albert',
#   'ModelTask': 'fill-mask'},
#  {'id': 6,
#   'LatestGitCommitSHA': '431c690c9f508b1cbcba8f475974833ac646d41c',
#   'ModelHub': {'MetadataFilePath': 'data/huggingface/json/metadata/hf_metadata.json',
#    'MetadataObjectID': 'albert-xxlarge-v1',
#    'ModelHubName': 'Hugging Face',
#    'ModelHubURL': 'https://huggingface.co/'},
#   'ModelName': 'albert-xxlarge-v1',
#   'ModelOwner': 'http://huggingface.co/',
#   'ModelOwnerURL': 'http://huggingface.co/',
#   'ModelURL': 'https://huggingface.co/albert-xxlarge-v1',
#   'ModelArchitecture': 'albert',
#   'ModelTask': 'fill-mask'},
#  {'id': 7,
#   'LatestGitCommitSHA': 'aaec31cf649a4d91a96b11f83eb5b2985eaf8ee5',
#   'ModelHub': {'MetadataFilePath': 'data/huggingface/json/metadata/hf_metadata.json',
#    'MetadataObjectID': 'albert-xxlarge-v2',
#    'ModelHubName': 'Hugging Face',
#    'ModelHubURL': 'https://huggingface.co/'},
#   'ModelName': 'albert-xxlarge-v2',
#   'ModelOwner': 'http://huggingface.co/',
#   'ModelOwnerURL': 'http://huggingface.co/',
#   'ModelURL': 'https://huggingface.co/albert-xxlarge-v2',
#   'ModelArchitecture': 'albert',
#   'ModelTask': 'fill-mask'},
#  {'id': 8,
#   'LatestGitCommitSHA': 'f53cb9cb49541a34be140979efe098073a179b0f',
#   'ModelHub': {'MetadataFilePath': 'data/huggingface/json/metadata/hf_metadata.json',
#    'MetadataObjectID': 'bert-base-cased-finetuned-mrpc',
#    'ModelHubName': 'Hugging Face',
#    'ModelHubURL': 'https://huggingface.co/'},
#   'ModelName': 'bert-base-cased-finetuned-mrpc',
#   'ModelOwner': 'http://huggingface.co/',
#   'ModelOwnerURL': 'http://huggingface.co/',
#   'ModelURL': 'https://huggingface.co/bert-base-cased-finetuned-mrpc',
#   'ModelArchitecture': 'bert',
#   'ModelTask': 'fill-mask'},
#  {'id': 9,
#   'LatestGitCommitSHA': '5532cc56f74641d4bb33641f5c76a55d11f846e0',
#   'ModelHub': {'MetadataFilePath': 'data/huggingface/json/metadata/hf_metadata.json',
#    'MetadataObjectID': 'bert-base-cased',
#    'ModelHubName': 'Hugging Face',
#    'ModelHubURL': 'https://huggingface.co/'},
#   'ModelName': 'bert-base-cased',
#   'ModelOwner': 'http://huggingface.co/',
#   'ModelOwnerURL': 'http://huggingface.co/',
#   'ModelURL': 'https://huggingface.co/bert-base-cased',
#   'ModelArchitecture': 'bert',
#   'ModelTask': 'fill-mask'},
#  {'id': 10,
#   'LatestGitCommitSHA': '84b432f646e4047ce1b5db001d43a348cd3f6bd0',
#   'ModelHub': {'MetadataFilePath': 'data/huggingface/json/metadata/hf_metadata.json',
#    'MetadataObjectID': 'bert-base-chinese',
#    'ModelHubName': 'Hugging Face',
#    'ModelHubURL': 'https://huggingface.co/'},
#   'ModelName': 'bert-base-chinese',
#   'ModelOwner': 'http://huggingface.co/',
#   'ModelOwnerURL': 'http://huggingface.co/',
#   'ModelURL': 'https://huggingface.co/bert-base-chinese',
#   'ModelArchitecture': 'bert',
#   'ModelTask': 'fill-mask'},
#  {'id': 11,
#   'LatestGitCommitSHA': '702774c02b32a4f360d5fea60ab034d64bf0141c',
#   'ModelHub': {'MetadataFilePath': 'data/huggingface/json/metadata/hf_metadata.json',
#    'MetadataObjectID': 'bert-base-german-cased',
#    'ModelHubName': 'Hugging Face',
#    'ModelHubURL': 'https://huggingface.co/'},
#   'ModelName': 'bert-base-german-cased',
#   'ModelOwner': 'http://huggingface.co/',
#   'ModelOwnerURL': 'http://huggingface.co/',
#   'ModelURL': 'https://huggingface.co/bert-base-german-cased',
#   'ModelArchitecture': 'bert',
#   'ModelTask': 'fill-mask'},
#  {'id': 12,
#   'LatestGitCommitSHA': '1338901726062fab13465d4b37f0f0c55b662a78',
#   'ModelHub': {'MetadataFilePath': 'data/huggingface/json/metadata/hf_metadata.json',
#    'MetadataObjectID': 'bert-base-german-dbmdz-cased',
#    'ModelHubName': 'Hugging Face',
#    'ModelHubURL': 'https://huggingface.co/'},
#   'ModelName': 'bert-base-german-dbmdz-cased',
#   'ModelOwner': 'http://huggingface.co/',
#   'ModelOwnerURL': 'http://huggingface.co/',
#   'ModelURL': 'https://huggingface.co/bert-base-german-dbmdz-cased',
#   'ModelArchitecture': 'bert',
#   'ModelTask': 'fill-mask'},
#  {'id': 13,
#   'LatestGitCommitSHA': '78540bb3887dee683eb7d1dc01abe831fe2d1b6d',
#   'ModelHub': {'MetadataFilePath': 'data/huggingface/json/metadata/hf_metadata.json',
#    'MetadataObjectID': 'bert-base-german-dbmdz-uncased',
#    'ModelHubName': 'Hugging Face',
#    'ModelHubURL': 'https://huggingface.co/'},
#   'ModelName': 'bert-base-german-dbmdz-uncased',
#   'ModelOwner': 'http://huggingface.co/',
#   'ModelOwnerURL': 'http://huggingface.co/',
#   'ModelURL': 'https://huggingface.co/bert-base-german-dbmdz-uncased',
#   'ModelArchitecture': 'bert',
#   'ModelTask': 'fill-mask'},
#  {'id': 14,
#   'LatestGitCommitSHA': 'fdfce55e83dbed325647a63e7e1f5de19f0382ba',
#   'ModelHub': {'MetadataFilePath': 'data/huggingface/json/metadata/hf_metadata.json',
#    'MetadataObjectID': 'bert-base-multilingual-cased',
#    'ModelHubName': 'Hugging Face',
#    'ModelHubURL': 'https://huggingface.co/'},
#   'ModelName': 'bert-base-multilingual-cased',
#   'ModelOwner': 'http://huggingface.co/',
#   'ModelOwnerURL': 'http://huggingface.co/',
#   'ModelURL': 'https://huggingface.co/bert-base-multilingual-cased',
#   'ModelArchitecture': 'bert',
#   'ModelTask': 'fill-mask'},
#  {'id': 15,
#   'LatestGitCommitSHA': '800c34f3d5aa174fe531f560b44b8d14592225b7',
#   'ModelHub': {'MetadataFilePath': 'data/huggingface/json/metadata/hf_metadata.json',
#    'MetadataObjectID': 'bert-base-multilingual-uncased',
#    'ModelHubName': 'Hugging Face',
#    'ModelHubURL': 'https://huggingface.co/'},
#   'ModelName': 'bert-base-multilingual-uncased',
#   'ModelOwner': 'http://huggingface.co/',
#   'ModelOwnerURL': 'http://huggingface.co/',
#   'ModelURL': 'https://huggingface.co/bert-base-multilingual-uncased',
#   'ModelArchitecture': 'bert',
#   'ModelTask': 'fill-mask'},
#  {'id': 16,
#   'LatestGitCommitSHA': '0a6aa9128b6194f4f3c4db429b6cb4891cdb421b',
#   'ModelHub': {'MetadataFilePath': 'data/huggingface/json/metadata/hf_metadata.json',
#    'MetadataObjectID': 'bert-base-uncased',
#    'ModelHubName': 'Hugging Face',
#    'ModelHubURL': 'https://huggingface.co/'},
#   'ModelName': 'bert-base-uncased',
#   'ModelOwner': 'http://huggingface.co/',
#   'ModelOwnerURL': 'http://huggingface.co/',
#   'ModelURL': 'https://huggingface.co/bert-base-uncased',
#   'ModelArchitecture': 'bert',
#   'ModelTask': 'fill-mask'},
#  {'id': 17,
#   'LatestGitCommitSHA': 'ba9ccd18e456b6c6a63a3ea5b21776f05452d923',
#   'ModelHub': {'MetadataFilePath': 'data/huggingface/json/metadata/hf_metadata.json',
#    'MetadataObjectID': 'bert-large-cased-whole-word-masking-finetuned-squad',
#    'ModelHubName': 'Hugging Face',
#    'ModelHubURL': 'https://huggingface.co/'},
#   'ModelName': 'bert-large-cased-whole-word-masking-finetuned-squad',
#   'ModelOwner': 'http://huggingface.co/',
#   'ModelOwnerURL': 'http://huggingface.co/',
#   'ModelURL': 'https://huggingface.co/bert-large-cased-whole-word-masking-finetuned-squad',
#   'ModelArchitecture': 'bert',
#   'ModelTask': 'question-answering'},
#  {'id': 18,
#   'LatestGitCommitSHA': '8b5d59881077680d99e2cac339412f20a180bd45',
#   'ModelHub': {'MetadataFilePath': 'data/huggingface/json/metadata/hf_metadata.json',
#    'MetadataObjectID': 'bert-large-cased-whole-word-masking',
#    'ModelHubName': 'Hugging Face',
#    'ModelHubURL': 'https://huggingface.co/'},
#   'ModelName': 'bert-large-cased-whole-word-masking',
#   'ModelOwner': 'http://huggingface.co/',
#   'ModelOwnerURL': 'http://huggingface.co/',
#   'ModelURL': 'https://huggingface.co/bert-large-cased-whole-word-masking',
#   'ModelArchitecture': 'bert',
#   'ModelTask': 'fill-mask'},
#  {'id': 19,
#   'LatestGitCommitSHA': 'd9238236d8326ce4bc117132bb3b7e62e95f3a9a',
#   'ModelHub': {'MetadataFilePath': 'data/huggingface/json/metadata/hf_metadata.json',
#    'MetadataObjectID': 'bert-large-cased',
#    'ModelHubName': 'Hugging Face',
#    'ModelHubURL': 'https://huggingface.co/'},
#   'ModelName': 'bert-large-cased',
#   'ModelOwner': 'http://huggingface.co/',
#   'ModelOwnerURL': 'http://huggingface.co/',
#   'ModelURL': 'https://huggingface.co/bert-large-cased',
#   'ModelArchitecture': 'bert',
#   'ModelTask': 'fill-mask'},
#  {'id': 20,
#   'LatestGitCommitSHA': '242d9dbb66bb5033025196d5678907307f8fb098',
#   'ModelHub': {'MetadataFilePath': 'data/huggingface/json/metadata/hf_metadata.json',
#    'MetadataObjectID': 'bert-large-uncased-whole-word-masking-finetuned-squad',
#    'ModelHubName': 'Hugging Face',
#    'ModelHubURL': 'https://huggingface.co/'},
#   'ModelName': 'bert-large-uncased-whole-word-masking-finetuned-squad',
#   'ModelOwner': 'http://huggingface.co/',
#   'ModelOwnerURL': 'http://huggingface.co/',
#   'ModelURL': 'https://huggingface.co/bert-large-uncased-whole-word-masking-finetuned-squad',
#   'ModelArchitecture': 'bert',
#   'ModelTask': 'question-answering'},
#  {'id': 21,
#   'LatestGitCommitSHA': '90d3333009848fae4860a5338419d17f70be940c',
#   'ModelHub': {'MetadataFilePath': 'data/huggingface/json/metadata/hf_metadata.json',
#    'MetadataObjectID': 'bert-large-uncased-whole-word-masking',
#    'ModelHubName': 'Hugging Face',
#    'ModelHubURL': 'https://huggingface.co/'},
#   'ModelName': 'bert-large-uncased-whole-word-masking',
#   'ModelOwner': 'http://huggingface.co/',
#   'ModelOwnerURL': 'http://huggingface.co/',
#   'ModelURL': 'https://huggingface.co/bert-large-uncased-whole-word-masking',
#   'ModelArchitecture': 'bert',
#   'ModelTask': 'fill-mask'},
#  {'id': 22,
#   'LatestGitCommitSHA': '80792f8e8216b29f3c846b653a0ff0a37c210431',
#   'ModelHub': {'MetadataFilePath': 'data/huggingface/json/metadata/hf_metadata.json',
#    'MetadataObjectID': 'bert-large-uncased',
#    'ModelHubName': 'Hugging Face',
#    'ModelHubURL': 'https://huggingface.co/'},
#   'ModelName': 'bert-large-uncased',
#   'ModelOwner': 'http://huggingface.co/',
#   'ModelOwnerURL': 'http://huggingface.co/',
#   'ModelURL': 'https://huggingface.co/bert-large-uncased',
#   'ModelArchitecture': 'bert',
#   'ModelTask': 'fill-mask'},
#  {'id': 23,
#   'LatestGitCommitSHA': '3f452b6e5a89b0e6c828c9bba2642bc577086eae',
#   'ModelHub': {'MetadataFilePath': 'data/huggingface/json/metadata/hf_metadata.json',
#    'MetadataObjectID': 'camembert-base',
#    'ModelHubName': 'Hugging Face',
#    'ModelHubURL': 'https://huggingface.co/'},
#   'ModelName': 'camembert-base',
#   'ModelOwner': 'http://huggingface.co/',
#   'ModelOwnerURL': 'http://huggingface.co/',
#   'ModelURL': 'https://huggingface.co/camembert-base',
#   'ModelArchitecture': 'camembert',
#   'ModelTask': 'fill-mask'},
#  {'id': 24,
#   'LatestGitCommitSHA': 'e3789f31af06f7dfbc086b59c562557a1d86d33b',
#   'ModelHub': {'MetadataFilePath': 'data/huggingface/json/metadata/hf_metadata.json',
#    'MetadataObjectID': 'ctrl',
#    'ModelHubName': 'Hugging Face',
#    'ModelHubURL': 'https://huggingface.co/'},
#   'ModelName': 'ctrl',
#   'ModelOwner': 'http://huggingface.co/',
#   'ModelOwnerURL': 'http://huggingface.co/',
#   'ModelURL': 'https://huggingface.co/ctrl',
#   'ModelArchitecture': 'ctrl'},
#  {'id': 25,
#   'LatestGitCommitSHA': 'a8440a9ab1b3d7a603df3349516078434abade1e',
#   'ModelHub': {'MetadataFilePath': 'data/huggingface/json/metadata/hf_metadata.json',
#    'MetadataObjectID': 'distilbert-base-cased-distilled-squad',
#    'ModelHubName': 'Hugging Face',
#    'ModelHubURL': 'https://huggingface.co/'},
#   'ModelName': 'distilbert-base-cased-distilled-squad',
#   'ModelOwner': 'http://huggingface.co/',
#   'ModelOwnerURL': 'http://huggingface.co/',
#   'ModelURL': 'https://huggingface.co/distilbert-base-cased-distilled-squad',
#   'ModelArchitecture': 'distilbert',
#   'ModelTask': 'question-answering'},
#  {'id': 26,
#   'LatestGitCommitSHA': '9d7568e4b20ed5db15ee30e99c7219bde9990762',
#   'ModelHub': {'MetadataFilePath': 'data/huggingface/json/metadata/hf_metadata.json',
#    'MetadataObjectID': 'distilbert-base-cased',
#    'ModelHubName': 'Hugging Face',
#    'ModelHubURL': 'https://huggingface.co/'},
#   'ModelName': 'distilbert-base-cased',
#   'ModelOwner': 'http://huggingface.co/',
#   'ModelOwnerURL': 'http://huggingface.co/',
#   'ModelURL': 'https://huggingface.co/distilbert-base-cased',
#   'ModelArchitecture': 'distilbert'},
#  {'id': 27,
#   'LatestGitCommitSHA': '06b1dc5ba050ddbf462d060df38f906eedb31b01',
#   'ModelHub': {'MetadataFilePath': 'data/huggingface/json/metadata/hf_metadata.json',
#    'MetadataObjectID': 'distilbert-base-german-cased',
#    'ModelHubName': 'Hugging Face',
#    'ModelHubURL': 'https://huggingface.co/'},
#   'ModelName': 'distilbert-base-german-cased',
#   'ModelOwner': 'http://huggingface.co/',
#   'ModelOwnerURL': 'http://huggingface.co/',
#   'ModelURL': 'https://huggingface.co/distilbert-base-german-cased',
#   'ModelArchitecture': 'distilbert',
#   'ModelTask': 'fill-mask'},
#  {'id': 28,
#   'LatestGitCommitSHA': 'fb240273126596a03b35c85793d2e82a5b13ac79',
#   'ModelHub': {'MetadataFilePath': 'data/huggingface/json/metadata/hf_metadata.json',
#    'MetadataObjectID': 'distilbert-base-multilingual-cased',
#    'ModelHubName': 'Hugging Face',
#    'ModelHubURL': 'https://huggingface.co/'},
#   'ModelName': 'distilbert-base-multilingual-cased',
#   'ModelOwner': 'http://huggingface.co/',
#   'ModelOwnerURL': 'http://huggingface.co/',
#   'ModelURL': 'https://huggingface.co/distilbert-base-multilingual-cased',
#   'ModelArchitecture': 'distilbert',
#   'ModelTask': 'fill-mask'},
#  {'id': 29,
#   'LatestGitCommitSHA': 'b82e3a1aaea09a786682861c68609122d8fe5d64',
#   'ModelHub': {'MetadataFilePath': 'data/huggingface/json/metadata/hf_metadata.json',
#    'MetadataObjectID': 'distilbert-base-uncased-distilled-squad',
#    'ModelHubName': 'Hugging Face',
#    'ModelHubURL': 'https://huggingface.co/'},
#   'ModelName': 'distilbert-base-uncased-distilled-squad',
#   'ModelOwner': 'http://huggingface.co/',
#   'ModelOwnerURL': 'http://huggingface.co/',
#   'ModelURL': 'https://huggingface.co/distilbert-base-uncased-distilled-squad',
#   'ModelArchitecture': 'distilbert',
#   'ModelTask': 'question-answering'},
#  {'id': 30,
#   'LatestGitCommitSHA': 'bfdd146ea2b6807255b73527f1327ca12b6ed5c4',
#   'ModelHub': {'MetadataFilePath': 'data/huggingface/json/metadata/hf_metadata.json',
#    'MetadataObjectID': 'distilbert-base-uncased-finetuned-sst-2-english',
#    'ModelHubName': 'Hugging Face',
#    'ModelHubURL': 'https://huggingface.co/'},
#   'ModelName': 'distilbert-base-uncased-finetuned-sst-2-english',
#   'ModelOwner': 'http://huggingface.co/',
#   'ModelOwnerURL': 'http://huggingface.co/',
#   'ModelURL': 'https://huggingface.co/distilbert-base-uncased-finetuned-sst-2-english',
#   'ModelArchitecture': 'distilbert',
#   'ModelPaperDOIs': ['doi:10.57967/hf/0181'],
#   'ModelTask': 'text-classification'},
#  {'id': 31,
#   'LatestGitCommitSHA': '1c4513b2eedbda136f57676a34eea67aba266e5c',
#   'ModelHub': {'MetadataFilePath': 'data/huggingface/json/metadata/hf_metadata.json',
#    'MetadataObjectID': 'distilbert-base-uncased',
#    'ModelHubName': 'Hugging Face',
#    'ModelHubURL': 'https://huggingface.co/'},
#   'ModelName': 'distilbert-base-uncased',
#   'ModelOwner': 'http://huggingface.co/',
#   'ModelOwnerURL': 'http://huggingface.co/',
#   'ModelURL': 'https://huggingface.co/distilbert-base-uncased',
#   'ModelArchitecture': 'distilbert',
#   'ModelTask': 'fill-mask'},
#  {'id': 32,
#   'LatestGitCommitSHA': 'f241065e938b44ac52db2c5de82c8bd2fafc76d0',
#   'ModelHub': {'MetadataFilePath': 'data/huggingface/json/metadata/hf_metadata.json',
#    'MetadataObjectID': 'distilgpt2',
#    'ModelHubName': 'Hugging Face',
#    'ModelHubURL': 'https://huggingface.co/'},
#   'ModelName': 'distilgpt2',
#   'ModelOwner': 'http://huggingface.co/',
#   'ModelOwnerURL': 'http://huggingface.co/',
#   'ModelURL': 'https://huggingface.co/distilgpt2',
#   'ModelArchitecture': 'gpt2',
#   'ModelTask': 'text-generation'},
#  {'id': 33,
#   'LatestGitCommitSHA': 'd5411c3ee9e1793fd9ef58390b40a80a4c10df32',
#   'ModelHub': {'MetadataFilePath': 'data/huggingface/json/metadata/hf_metadata.json',
#    'MetadataObjectID': 'distilroberta-base',
#    'ModelHubName': 'Hugging Face',
#    'ModelHubURL': 'https://huggingface.co/'},
#   'ModelName': 'distilroberta-base',
#   'ModelOwner': 'http://huggingface.co/',
#   'ModelOwnerURL': 'http://huggingface.co/',
#   'ModelURL': 'https://huggingface.co/distilroberta-base',
#   'ModelArchitecture': 'roberta',
#   'ModelTask': 'fill-mask'},
#  {'id': 34,
#   'LatestGitCommitSHA': 'b54dbc3879361633ba43e2df284fd21de7c8d4a4',
#   'ModelHub': {'MetadataFilePath': 'data/huggingface/json/metadata/hf_metadata.json',
#    'MetadataObjectID': 'gpt2-large',
#    'ModelHubName': 'Hugging Face',
#    'ModelHubURL': 'https://huggingface.co/'},
#   'ModelName': 'gpt2-large',
#   'ModelOwner': 'http://huggingface.co/',
#   'ModelOwnerURL': 'http://huggingface.co/',
#   'ModelURL': 'https://huggingface.co/gpt2-large',
#   'ModelArchitecture': 'gpt2',
#   'ModelTask': 'text-generation'},
#  {'id': 35,
#   'LatestGitCommitSHA': 'a8543b814a49bbee7dee6faa0a915c90f461f4d5',
#   'ModelHub': {'MetadataFilePath': 'data/huggingface/json/metadata/hf_metadata.json',
#    'MetadataObjectID': 'gpt2-medium',
#    'ModelHubName': 'Hugging Face',
#    'ModelHubURL': 'https://huggingface.co/'},
#   'ModelName': 'gpt2-medium',
#   'ModelOwner': 'http://huggingface.co/',
#   'ModelOwnerURL': 'http://huggingface.co/',
#   'ModelURL': 'https://huggingface.co/gpt2-medium',
#   'ModelArchitecture': 'gpt2',
#   'ModelTask': 'text-generation'},
#  {'id': 36,
#   'LatestGitCommitSHA': '33cdb5c0db5423c1879b1b9f16c352988e8754a8',
#   'ModelHub': {'MetadataFilePath': 'data/huggingface/json/metadata/hf_metadata.json',
#    'MetadataObjectID': 'gpt2-xl',
#    'ModelHubName': 'Hugging Face',
#    'ModelHubURL': 'https://huggingface.co/'},
#   'ModelName': 'gpt2-xl',
#   'ModelOwner': 'http://huggingface.co/',
#   'ModelOwnerURL': 'http://huggingface.co/',
#   'ModelURL': 'https://huggingface.co/gpt2-xl',
#   'ModelArchitecture': 'gpt2',
#   'ModelTask': 'text-generation'},
#  {'id': 37,
#   'LatestGitCommitSHA': 'e7da7f221d5bf496a48136c0cd264e630fe9fcc8',
#   'ModelHub': {'MetadataFilePath': 'data/huggingface/json/metadata/hf_metadata.json',
#    'MetadataObjectID': 'gpt2',
#    'ModelHubName': 'Hugging Face',
#    'ModelHubURL': 'https://huggingface.co/'},
#   'ModelName': 'gpt2',
#   'ModelOwner': 'http://huggingface.co/',
#   'ModelOwnerURL': 'http://huggingface.co/',
#   'ModelURL': 'https://huggingface.co/gpt2',
#   'ModelArchitecture': 'gpt2',
#   'ModelPaperDOIs': ['doi:10.57967/hf/0039'],
#   'ModelTask': 'text-generation'},
#  {'id': 38,
#   'LatestGitCommitSHA': '173722e0fb291a67357ef55b1c66ed4474021b82',
#   'ModelHub': {'MetadataFilePath': 'data/huggingface/json/metadata/hf_metadata.json',
#    'MetadataObjectID': 'openai-gpt',
#    'ModelHubName': 'Hugging Face',
#    'ModelHubURL': 'https://huggingface.co/'},
#   'ModelName': 'openai-gpt',
#   'ModelOwner': 'http://huggingface.co/',
#   'ModelOwnerURL': 'http://huggingface.co/',
#   'ModelURL': 'https://huggingface.co/openai-gpt',
#   'ModelArchitecture': 'openai-gpt',
#   'ModelTask': 'text-generation'},
#  {'id': 39,
#   'LatestGitCommitSHA': '8bdaf8823e2e58aaa3716eabc607f05b631b7273',
#   'ModelHub': {'MetadataFilePath': 'data/huggingface/json/metadata/hf_metadata.json',
#    'MetadataObjectID': 'roberta-base-openai-detector',
#    'ModelHubName': 'Hugging Face',
#    'ModelHubURL': 'https://huggingface.co/'},
#   'ModelName': 'roberta-base-openai-detector',
#   'ModelOwner': 'http://huggingface.co/',
#   'ModelOwnerURL': 'http://huggingface.co/',
#   'ModelURL': 'https://huggingface.co/roberta-base-openai-detector',
#   'ModelArchitecture': 'roberta',
#   'ModelTask': 'text-classification'},
#  {'id': 40,
#   'LatestGitCommitSHA': 'ff46155979338ff8063cdad90908b498ab91b181',
#   'ModelHub': {'MetadataFilePath': 'data/huggingface/json/metadata/hf_metadata.json',
#    'MetadataObjectID': 'roberta-base',
#    'ModelHubName': 'Hugging Face',
#    'ModelHubURL': 'https://huggingface.co/'},
#   'ModelName': 'roberta-base',
#   'ModelOwner': 'http://huggingface.co/',
#   'ModelOwnerURL': 'http://huggingface.co/',
#   'ModelURL': 'https://huggingface.co/roberta-base',
#   'ModelArchitecture': 'roberta',
#   'ModelTask': 'fill-mask'},
#  {'id': 41,
#   'LatestGitCommitSHA': '0dcbcf20673c006ac2d1e324954491b96f0c0015',
#   'ModelHub': {'MetadataFilePath': 'data/huggingface/json/metadata/hf_metadata.json',
#    'MetadataObjectID': 'roberta-large-mnli',
#    'ModelHubName': 'Hugging Face',
#    'ModelHubURL': 'https://huggingface.co/'},
#   'ModelName': 'roberta-large-mnli',
#   'ModelOwner': 'http://huggingface.co/',
#   'ModelOwnerURL': 'http://huggingface.co/',
#   'ModelURL': 'https://huggingface.co/roberta-large-mnli',
#   'ModelArchitecture': 'roberta',
#   'ModelTask': 'text-classification'},
#  {'id': 42,
#   'LatestGitCommitSHA': '5002d695ecf610d8bbfb1fa0d14f1575185b4915',
#   'ModelHub': {'MetadataFilePath': 'data/huggingface/json/metadata/hf_metadata.json',
#    'MetadataObjectID': 'roberta-large-openai-detector',
#    'ModelHubName': 'Hugging Face',
#    'ModelHubURL': 'https://huggingface.co/'},
#   'ModelName': 'roberta-large-openai-detector',
#   'ModelOwner': 'http://huggingface.co/',
#   'ModelOwnerURL': 'http://huggingface.co/',
#   'ModelURL': 'https://huggingface.co/roberta-large-openai-detector',
#   'ModelArchitecture': 'roberta',
#   'ModelTask': 'text-classification'},
#  {'id': 43,
#   'LatestGitCommitSHA': '5069d8a2a32a7df4c69ef9b56348be04152a2341',
#   'ModelHub': {'MetadataFilePath': 'data/huggingface/json/metadata/hf_metadata.json',
#    'MetadataObjectID': 'roberta-large',
#    'ModelHubName': 'Hugging Face',
#    'ModelHubURL': 'https://huggingface.co/'},
#   'ModelName': 'roberta-large',
#   'ModelOwner': 'http://huggingface.co/',
#   'ModelOwnerURL': 'http://huggingface.co/',
#   'ModelURL': 'https://huggingface.co/roberta-large',
#   'ModelArchitecture': 'roberta',
#   'ModelTask': 'fill-mask'},
#  {'id': 44,
#   'LatestGitCommitSHA': '90f37703b3334dfe9d2b009bfcbfbf1ac9d28ea3',
#   'ModelHub': {'MetadataFilePath': 'data/huggingface/json/metadata/hf_metadata.json',
#    'MetadataObjectID': 't5-11b',
#    'ModelHubName': 'Hugging Face',
#    'ModelHubURL': 'https://huggingface.co/'},
#   'ModelName': 't5-11b',
#   'ModelOwner': 'http://huggingface.co/',
#   'ModelOwnerURL': 'http://huggingface.co/',
#   'ModelURL': 'https://huggingface.co/t5-11b',
#   'ModelArchitecture': 't5',
#   'ModelTask': 'translation'},
#  {'id': 45,
#   'LatestGitCommitSHA': '343bb43e4bd40169cb9e64fa9842e6f04122618b',
#   'ModelHub': {'MetadataFilePath': 'data/huggingface/json/metadata/hf_metadata.json',
#    'MetadataObjectID': 't5-3b',
#    'ModelHubName': 'Hugging Face',
#    'ModelHubURL': 'https://huggingface.co/'},
#   'ModelName': 't5-3b',
#   'ModelOwner': 'http://huggingface.co/',
#   'ModelOwnerURL': 'http://huggingface.co/',
#   'ModelURL': 'https://huggingface.co/t5-3b',
#   'ModelArchitecture': 't5',
#   'ModelTask': 'translation'},
#  {'id': 46,
#   'LatestGitCommitSHA': '0db7e623bcaee2daf9b859a646637ea39bf016cd',
#   'ModelHub': {'MetadataFilePath': 'data/huggingface/json/metadata/hf_metadata.json',
#    'MetadataObjectID': 't5-base',
#    'ModelHubName': 'Hugging Face',
#    'ModelHubURL': 'https://huggingface.co/'},
#   'ModelName': 't5-base',
#   'ModelOwner': 'http://huggingface.co/',
#   'ModelOwnerURL': 'http://huggingface.co/',
#   'ModelURL': 'https://huggingface.co/t5-base',
#   'ModelArchitecture': 't5',
#   'ModelTask': 'translation'},
#  {'id': 47,
#   'LatestGitCommitSHA': '6ed159b7a9408621a1ed0b9ca39aacc42c694d73',
#   'ModelHub': {'MetadataFilePath': 'data/huggingface/json/metadata/hf_metadata.json',
#    'MetadataObjectID': 't5-large',
#    'ModelHubName': 'Hugging Face',
#    'ModelHubURL': 'https://huggingface.co/'},
#   'ModelName': 't5-large',
#   'ModelOwner': 'http://huggingface.co/',
#   'ModelOwnerURL': 'http://huggingface.co/',
#   'ModelURL': 'https://huggingface.co/t5-large',
#   'ModelArchitecture': 't5',
#   'ModelTask': 'translation'},
#  {'id': 48,
#   'LatestGitCommitSHA': '3479082dc36f8a4730936ef1c9b88cd8b0835c53',
#   'ModelHub': {'MetadataFilePath': 'data/huggingface/json/metadata/hf_metadata.json',
#    'MetadataObjectID': 't5-small',
#    'ModelHubName': 'Hugging Face',
#    'ModelHubURL': 'https://huggingface.co/'},
#   'ModelName': 't5-small',
#   'ModelOwner': 'http://huggingface.co/',
#   'ModelOwnerURL': 'http://huggingface.co/',
#   'ModelURL': 'https://huggingface.co/t5-small',
#   'ModelArchitecture': 't5',
#   'ModelTask': 'translation'},
#  {'id': 49,
#   'LatestGitCommitSHA': '40a186da79458c9f9de846edfaea79c412137f97',
#   'ModelHub': {'MetadataFilePath': 'data/huggingface/json/metadata/hf_metadata.json',
#    'MetadataObjectID': 'transfo-xl-wt103',
#    'ModelHubName': 'Hugging Face',
#    'ModelHubURL': 'https://huggingface.co/'},
#   'ModelName': 'transfo-xl-wt103',
#   'ModelOwner': 'http://huggingface.co/',
#   'ModelOwnerURL': 'http://huggingface.co/',
#   'ModelURL': 'https://huggingface.co/transfo-xl-wt103',
#   'ModelArchitecture': 'transfo-xl',
#   'ModelTask': 'text-generation'},
#  {'id': 50,
#   'LatestGitCommitSHA': '22a7773a882bbaba77a6459a14826f8c6f1fb776',
#   'ModelHub': {'MetadataFilePath': 'data/huggingface/json/metadata/hf_metadata.json',
#    'MetadataObjectID': 'xlm-clm-ende-1024',
#    'ModelHubName': 'Hugging Face',
#    'ModelHubURL': 'https://huggingface.co/'},
#   'ModelName': 'xlm-clm-ende-1024',
#   'ModelOwner': 'http://huggingface.co/',
#   'ModelOwnerURL': 'http://huggingface.co/',
#   'ModelURL': 'https://huggingface.co/xlm-clm-ende-1024',
#   'ModelArchitecture': 'xlm',
#   'ModelTask': 'fill-mask'},
#  {'id': 51,
#   'LatestGitCommitSHA': '715cf0b3b4486b757a707886e62ae8e906867a18',
#   'ModelHub': {'MetadataFilePath': 'data/huggingface/json/metadata/hf_metadata.json',
#    'MetadataObjectID': 'xlm-clm-enfr-1024',
#    'ModelHubName': 'Hugging Face',
#    'ModelHubURL': 'https://huggingface.co/'},
#   'ModelName': 'xlm-clm-enfr-1024',
#   'ModelOwner': 'http://huggingface.co/',
#   'ModelOwnerURL': 'http://huggingface.co/',
#   'ModelURL': 'https://huggingface.co/xlm-clm-enfr-1024',
#   'ModelArchitecture': 'xlm',
#   'ModelTask': 'fill-mask'},
#  {'id': 52,
#   'LatestGitCommitSHA': '73d3bed88b06e65b306c6b50e00503f0e8788846',
#   'ModelHub': {'MetadataFilePath': 'data/huggingface/json/metadata/hf_metadata.json',
#    'MetadataObjectID': 'xlm-mlm-100-1280',
#    'ModelHubName': 'Hugging Face',
#    'ModelHubURL': 'https://huggingface.co/'},
#   'ModelName': 'xlm-mlm-100-1280',
#   'ModelOwner': 'http://huggingface.co/',
#   'ModelOwnerURL': 'http://huggingface.co/',
#   'ModelURL': 'https://huggingface.co/xlm-mlm-100-1280',
#   'ModelArchitecture': 'xlm',
#   'ModelTask': 'fill-mask'},
#  {'id': 53,
#   'LatestGitCommitSHA': '8ec626c19ed18c15b6be954728b7a625340bb57f',
#   'ModelHub': {'MetadataFilePath': 'data/huggingface/json/metadata/hf_metadata.json',
#    'MetadataObjectID': 'xlm-mlm-17-1280',
#    'ModelHubName': 'Hugging Face',
#    'ModelHubURL': 'https://huggingface.co/'},
#   'ModelName': 'xlm-mlm-17-1280',
#   'ModelOwner': 'http://huggingface.co/',
#   'ModelOwnerURL': 'http://huggingface.co/',
#   'ModelURL': 'https://huggingface.co/xlm-mlm-17-1280',
#   'ModelArchitecture': 'xlm',
#   'ModelTask': 'fill-mask'},
#  {'id': 54,
#   'LatestGitCommitSHA': '6eb6401a142611ae90f3d6bc606b97384f1c9961',
#   'ModelHub': {'MetadataFilePath': 'data/huggingface/json/metadata/hf_metadata.json',
#    'MetadataObjectID': 'xlm-mlm-en-2048',
#    'ModelHubName': 'Hugging Face',
#    'ModelHubURL': 'https://huggingface.co/'},
#   'ModelName': 'xlm-mlm-en-2048',
#   'ModelOwner': 'http://huggingface.co/',
#   'ModelOwnerURL': 'http://huggingface.co/',
#   'ModelURL': 'https://huggingface.co/xlm-mlm-en-2048',
#   'ModelArchitecture': 'xlm',
#   'ModelTask': 'fill-mask'},
#  {'id': 55,
#   'LatestGitCommitSHA': 'a85effc0e8010667d519995ea43f6c417b942491',
#   'ModelHub': {'MetadataFilePath': 'data/huggingface/json/metadata/hf_metadata.json',
#    'MetadataObjectID': 'xlm-mlm-ende-1024',
#    'ModelHubName': 'Hugging Face',
#    'ModelHubURL': 'https://huggingface.co/'},
#   'ModelName': 'xlm-mlm-ende-1024',
#   'ModelOwner': 'http://huggingface.co/',
#   'ModelOwnerURL': 'http://huggingface.co/',
#   'ModelURL': 'https://huggingface.co/xlm-mlm-ende-1024',
#   'ModelArchitecture': 'xlm',
#   'ModelTask': 'fill-mask'},
#  {'id': 56,
#   'LatestGitCommitSHA': '4a50a9268380b7f6460ab4d8239c0375d4ee0128',
#   'ModelHub': {'MetadataFilePath': 'data/huggingface/json/metadata/hf_metadata.json',
#    'MetadataObjectID': 'xlm-mlm-enfr-1024',
#    'ModelHubName': 'Hugging Face',
#    'ModelHubURL': 'https://huggingface.co/'},
#   'ModelName': 'xlm-mlm-enfr-1024',
#   'ModelOwner': 'http://huggingface.co/',
#   'ModelOwnerURL': 'http://huggingface.co/',
#   'ModelURL': 'https://huggingface.co/xlm-mlm-enfr-1024',
#   'ModelArchitecture': 'xlm',
#   'ModelTask': 'fill-mask'},
#  {'id': 57,
#   'LatestGitCommitSHA': '61378ebba943c1444737bd89628635a9feec010b',
#   'ModelHub': {'MetadataFilePath': 'data/huggingface/json/metadata/hf_metadata.json',
#    'MetadataObjectID': 'xlm-mlm-enro-1024',
#    'ModelHubName': 'Hugging Face',
#    'ModelHubURL': 'https://huggingface.co/'},
#   'ModelName': 'xlm-mlm-enro-1024',
#   'ModelOwner': 'http://huggingface.co/',
#   'ModelOwnerURL': 'http://huggingface.co/',
#   'ModelURL': 'https://huggingface.co/xlm-mlm-enro-1024',
#   'ModelArchitecture': 'xlm',
#   'ModelTask': 'fill-mask'},
#  {'id': 58,
#   'LatestGitCommitSHA': '9d175e90efcddbbdd305e5b7290196e226c22daf',
#   'ModelHub': {'MetadataFilePath': 'data/huggingface/json/metadata/hf_metadata.json',
#    'MetadataObjectID': 'xlm-mlm-tlm-xnli15-1024',
#    'ModelHubName': 'Hugging Face',
#    'ModelHubURL': 'https://huggingface.co/'},
#   'ModelName': 'xlm-mlm-tlm-xnli15-1024',
#   'ModelOwner': 'http://huggingface.co/',
#   'ModelOwnerURL': 'http://huggingface.co/',
#   'ModelURL': 'https://huggingface.co/xlm-mlm-tlm-xnli15-1024',
#   'ModelArchitecture': 'xlm',
#   'ModelTask': 'fill-mask'},
#  {'id': 59,
#   'LatestGitCommitSHA': '9eb45670cf182905cff97fb54d05fb846a1902fe',
#   'ModelHub': {'MetadataFilePath': 'data/huggingface/json/metadata/hf_metadata.json',
#    'MetadataObjectID': 'xlm-mlm-xnli15-1024',
#    'ModelHubName': 'Hugging Face',
#    'ModelHubURL': 'https://huggingface.co/'},
#   'ModelName': 'xlm-mlm-xnli15-1024',
#   'ModelOwner': 'http://huggingface.co/',
#   'ModelOwnerURL': 'http://huggingface.co/',
#   'ModelURL': 'https://huggingface.co/xlm-mlm-xnli15-1024',
#   'ModelArchitecture': 'xlm',
#   'ModelTask': 'fill-mask'},
#  {'id': 60,
#   'LatestGitCommitSHA': '42f548f32366559214515ec137cdd16002968bf6',
#   'ModelHub': {'MetadataFilePath': 'data/huggingface/json/metadata/hf_metadata.json',
#    'MetadataObjectID': 'xlm-roberta-base',
#    'ModelHubName': 'Hugging Face',
#    'ModelHubURL': 'https://huggingface.co/'},
#   'ModelName': 'xlm-roberta-base',
#   'ModelOwner': 'http://huggingface.co/',
#   'ModelOwnerURL': 'http://huggingface.co/',
#   'ModelURL': 'https://huggingface.co/xlm-roberta-base',
#   'ModelArchitecture': 'xlm-roberta',
#   'ModelTask': 'fill-mask'},
#  {'id': 61,
#   'LatestGitCommitSHA': 'c0a0c5196da660dc28bc80e9d94edd28b35fc4e5',
#   'ModelHub': {'MetadataFilePath': 'data/huggingface/json/metadata/hf_metadata.json',
#    'MetadataObjectID': 'xlm-roberta-large-finetuned-conll02-dutch',
#    'ModelHubName': 'Hugging Face',
#    'ModelHubURL': 'https://huggingface.co/'},
#   'ModelName': 'xlm-roberta-large-finetuned-conll02-dutch',
#   'ModelOwner': 'http://huggingface.co/',
#   'ModelOwnerURL': 'http://huggingface.co/',
#   'ModelURL': 'https://huggingface.co/xlm-roberta-large-finetuned-conll02-dutch',
#   'ModelArchitecture': 'xlm-roberta',
#   'ModelTask': 'fill-mask'},
#  {'id': 62,
#   'LatestGitCommitSHA': '9224ae48fe1128e0bd8c5b43738a144d6ce5e335',
#   'ModelHub': {'MetadataFilePath': 'data/huggingface/json/metadata/hf_metadata.json',
#    'MetadataObjectID': 'xlm-roberta-large-finetuned-conll02-spanish',
#    'ModelHubName': 'Hugging Face',
#    'ModelHubURL': 'https://huggingface.co/'},
#   'ModelName': 'xlm-roberta-large-finetuned-conll02-spanish',
#   'ModelOwner': 'http://huggingface.co/',
#   'ModelOwnerURL': 'http://huggingface.co/',
#   'ModelURL': 'https://huggingface.co/xlm-roberta-large-finetuned-conll02-spanish',
#   'ModelArchitecture': 'xlm-roberta',
#   'ModelTask': 'fill-mask'},
#  {'id': 63,
#   'LatestGitCommitSHA': '33a83d9855a119c0453ce450858c07835a0bdbed',
#   'ModelHub': {'MetadataFilePath': 'data/huggingface/json/metadata/hf_metadata.json',
#    'MetadataObjectID': 'xlm-roberta-large-finetuned-conll03-english',
#    'ModelHubName': 'Hugging Face',
#    'ModelHubURL': 'https://huggingface.co/'},
#   'ModelName': 'xlm-roberta-large-finetuned-conll03-english',
#   'ModelOwner': 'http://huggingface.co/',
#   'ModelOwnerURL': 'http://huggingface.co/',
#   'ModelURL': 'https://huggingface.co/xlm-roberta-large-finetuned-conll03-english',
#   'ModelArchitecture': 'xlm-roberta',
#   'ModelTask': 'token-classification'},
#  {'id': 64,
#   'LatestGitCommitSHA': '737aa82161f5a202e95012eebfe78ef597d980ec',
#   'ModelHub': {'MetadataFilePath': 'data/huggingface/json/metadata/hf_metadata.json',
#    'MetadataObjectID': 'xlm-roberta-large-finetuned-conll03-german',
#    'ModelHubName': 'Hugging Face',
#    'ModelHubURL': 'https://huggingface.co/'},
#   'ModelName': 'xlm-roberta-large-finetuned-conll03-german',
#   'ModelOwner': 'http://huggingface.co/',
#   'ModelOwnerURL': 'http://huggingface.co/',
#   'ModelURL': 'https://huggingface.co/xlm-roberta-large-finetuned-conll03-german',
#   'ModelArchitecture': 'xlm-roberta',
#   'ModelTask': 'token-classification'},
#  {'id': 65,
#   'LatestGitCommitSHA': 'b2a6150f8be56457baf80c74342cc424080260f0',
#   'ModelHub': {'MetadataFilePath': 'data/huggingface/json/metadata/hf_metadata.json',
#    'MetadataObjectID': 'xlm-roberta-large',
#    'ModelHubName': 'Hugging Face',
#    'ModelHubURL': 'https://huggingface.co/'},
#   'ModelName': 'xlm-roberta-large',
#   'ModelOwner': 'http://huggingface.co/',
#   'ModelOwnerURL': 'http://huggingface.co/',
#   'ModelURL': 'https://huggingface.co/xlm-roberta-large',
#   'ModelArchitecture': 'xlm-roberta',
#   'ModelTask': 'fill-mask'},
#  {'id': 66,
#   'LatestGitCommitSHA': 'ceaa69c7bc5e512b5007106a7ccbb7daf24b2c79',
#   'ModelHub': {'MetadataFilePath': 'data/huggingface/json/metadata/hf_metadata.json',
#    'MetadataObjectID': 'xlnet-base-cased',
#    'ModelHubName': 'Hugging Face',
#    'ModelHubURL': 'https://huggingface.co/'},
#   'ModelName': 'xlnet-base-cased',
#   'ModelOwner': 'http://huggingface.co/',
#   'ModelOwnerURL': 'http://huggingface.co/',
#   'ModelURL': 'https://huggingface.co/xlnet-base-cased',
#   'ModelArchitecture': 'xlnet',
#   'ModelTask': 'text-generation'},
#  {'id': 67,
#   'LatestGitCommitSHA': '37658b4f179eaf971d127d16bfbd9ca676a93034',
#   'ModelHub': {'MetadataFilePath': 'data/huggingface/json/metadata/hf_metadata.json',
#    'MetadataObjectID': 'xlnet-large-cased',
#    'ModelHubName': 'Hugging Face',
#    'ModelHubURL': 'https://huggingface.co/'},
#   'ModelName': 'xlnet-large-cased',
#   'ModelOwner': 'http://huggingface.co/',
#   'ModelOwnerURL': 'http://huggingface.co/',
#   'ModelURL': 'https://huggingface.co/xlnet-large-cased',
#   'ModelArchitecture': 'xlnet',
#   'ModelTask': 'text-generation'},
#  {'id': 68,
#   'LatestGitCommitSHA': 'f7b02944db5d99ed5c55a7a4e9225d8bdfd147b2',
#   'ModelHub': {'MetadataFilePath': 'data/huggingface/json/metadata/hf_metadata.json',
#    'MetadataObjectID': '007J/smile',
#    'ModelHubName': 'Hugging Face',
#    'ModelHubURL': 'https://huggingface.co/'},
#   'ModelName': '007J/smile',
#   'ModelOwner': '007J',
#   'ModelOwnerURL': 'https://huggingface.co/007J',
#   'ModelURL': 'https://huggingface.co/007J/smile'},
#  {'id': 69,
#   'LatestGitCommitSHA': '4aceb71949b617e37d3173c10eb7bfdabc2d426c',
#   'ModelHub': {'MetadataFilePath': 'data/huggingface/json/metadata/hf_metadata.json',
#    'MetadataObjectID': '0307061430/xuangou',
#    'ModelHubName': 'Hugging Face',
#    'ModelHubURL': 'https://huggingface.co/'},
#   'ModelName': '0307061430/xuangou',
#   'ModelOwner': '0307061430',
#   'ModelOwnerURL': 'https://huggingface.co/0307061430',
#   'ModelURL': 'https://huggingface.co/0307061430/xuangou'},
#  {'id': 70,
#   'LatestGitCommitSHA': 'f89a85cb8703676115912fffa55842f23eb981ab',
#   'ModelHub': {'MetadataFilePath': 'data/huggingface/json/metadata/hf_metadata.json',
#    'MetadataObjectID': '09panesara/distilbert-base-uncased-finetuned-cola',
#    'ModelHubName': 'Hugging Face',
#    'ModelHubURL': 'https://huggingface.co/'},
#   'ModelName': '09panesara/distilbert-base-uncased-finetuned-cola',
#   'ModelOwner': '09panesara',
#   'ModelOwnerURL': 'https://huggingface.co/09panesara',
#   'ModelURL': 'https://huggingface.co/09panesara/distilbert-base-uncased-finetuned-cola',
#   'ModelArchitecture': 'distilbert',
#   'ModelTask': 'text-classification'},
#  {'id': 71,
#   'LatestGitCommitSHA': '591b9e9121e617461e1a0c8d552109c153610c05',
#   'ModelHub': {'MetadataFilePath': 'data/huggingface/json/metadata/hf_metadata.json',
#    'MetadataObjectID': '0x7194633/keyt5-base',
#    'ModelHubName': 'Hugging Face',
#    'ModelHubURL': 'https://huggingface.co/'},
#   'ModelName': '0x7194633/keyt5-base',
#   'ModelOwner': '0x7194633',
#   'ModelOwnerURL': 'https://huggingface.co/0x7194633',
#   'ModelURL': 'https://huggingface.co/0x7194633/keyt5-base',
#   'ModelArchitecture': 't5',
#   'ModelTask': 'text2text-generation'},
#  {'id': 72,
#   'LatestGitCommitSHA': '6aca9fe5edca51e69d13734271c0c60793c16831',
#   'ModelHub': {'MetadataFilePath': 'data/huggingface/json/metadata/hf_metadata.json',
#    'MetadataObjectID': '0x7194633/keyt5-large',
#    'ModelHubName': 'Hugging Face',
#    'ModelHubURL': 'https://huggingface.co/'},
#   'ModelName': '0x7194633/keyt5-large',
#   'ModelOwner': '0x7194633',
#   'ModelOwnerURL': 'https://huggingface.co/0x7194633',
#   'ModelURL': 'https://huggingface.co/0x7194633/keyt5-large',
#   'ModelArchitecture': 't5',
#   'ModelTask': 'text2text-generation'},
#  {'id': 73,
#   'LatestGitCommitSHA': 'c1d2dd6d26adb9a682148b406ffc50d73512f132',
#   'ModelHub': {'MetadataFilePath': 'data/huggingface/json/metadata/hf_metadata.json',
#    'MetadataObjectID': '0xDEADBEA7/DialoGPT-small-rick',
#    'ModelHubName': 'Hugging Face',
#    'ModelHubURL': 'https://huggingface.co/'},
#   'ModelName': '0xDEADBEA7/DialoGPT-small-rick',
#   'ModelOwner': '0xDEADBEA7',
#   'ModelOwnerURL': 'https://huggingface.co/0xDEADBEA7',
#   'ModelURL': 'https://huggingface.co/0xDEADBEA7/DialoGPT-small-rick',
#   'ModelArchitecture': 'gpt2',
#   'ModelTask': 'conversational'},
#  {'id': 74,
#   'LatestGitCommitSHA': '34927266eb36532af4e40764a8868b70f4b96641',
#   'ModelHub': {'MetadataFilePath': 'data/huggingface/json/metadata/hf_metadata.json',
#    'MetadataObjectID': '123123/ghfk',
#    'ModelHubName': 'Hugging Face',
#    'ModelHubURL': 'https://huggingface.co/'},
#   'ModelName': '123123/ghfk',
#   'ModelOwner': '123123',
#   'ModelOwnerURL': 'https://huggingface.co/123123',
#   'ModelURL': 'https://huggingface.co/123123/ghfk'},
#  {'id': 75,
#   'LatestGitCommitSHA': 'f72be46a573afdbae684d4a70c2a44a15a7579a5',
#   'ModelHub': {'MetadataFilePath': 'data/huggingface/json/metadata/hf_metadata.json',
#    'MetadataObjectID': '123456/Arcanegan',
#    'ModelHubName': 'Hugging Face',
#    'ModelHubURL': 'https://huggingface.co/'},
#   'ModelName': '123456/Arcanegan',
#   'ModelOwner': '123456',
#   'ModelOwnerURL': 'https://huggingface.co/123456',
#   'ModelURL': 'https://huggingface.co/123456/Arcanegan'},
#  {'id': 76,
#   'LatestGitCommitSHA': 'cad69e5ecc2e40702451950af6261c58b1c9ffea',
#   'ModelHub': {'MetadataFilePath': 'data/huggingface/json/metadata/hf_metadata.json',
#    'MetadataObjectID': '1234567/1234567',
#    'ModelHubName': 'Hugging Face',
#    'ModelHubURL': 'https://huggingface.co/'},
#   'ModelName': '1234567/1234567',
#   'ModelOwner': '1234567',
#   'ModelOwnerURL': 'https://huggingface.co/1234567',
#   'ModelURL': 'https://huggingface.co/1234567/1234567'},
#  {'id': 77,
#   'LatestGitCommitSHA': '2eab0af7661abe374099575423186026d4ee6bc6',
#   'ModelHub': {'MetadataFilePath': 'data/huggingface/json/metadata/hf_metadata.json',
#    'MetadataObjectID': '123abhiALFLKFO/albert-base-v2-finetuned-sst2',
#    'ModelHubName': 'Hugging Face',
#    'ModelHubURL': 'https://huggingface.co/'},
#   'ModelName': '123abhiALFLKFO/albert-base-v2-finetuned-sst2',
#   'ModelOwner': '123abhiALFLKFO',
#   'ModelOwnerURL': 'https://huggingface.co/123abhiALFLKFO',
#   'ModelURL': 'https://huggingface.co/123abhiALFLKFO/albert-base-v2-finetuned-sst2'},
#  {'id': 78,
#   'LatestGitCommitSHA': '471fc0503ee8e9eb37c4090c5b154a911c0e412b',
#   'ModelHub': {'MetadataFilePath': 'data/huggingface/json/metadata/hf_metadata.json',
#    'MetadataObjectID': '123abhiALFLKFO/albert-base-v2-yelp-polarity-finetuned-sst2',
#    'ModelHubName': 'Hugging Face',
#    'ModelHubURL': 'https://huggingface.co/'},
#   'ModelName': '123abhiALFLKFO/albert-base-v2-yelp-polarity-finetuned-sst2',
#   'ModelOwner': '123abhiALFLKFO',
#   'ModelOwnerURL': 'https://huggingface.co/123abhiALFLKFO',
#   'ModelURL': 'https://huggingface.co/123abhiALFLKFO/albert-base-v2-yelp-polarity-finetuned-sst2'},
#  {'id': 79,
#   'LatestGitCommitSHA': '22e60ac571915fa1fa5e79c8f8804565cc07fd69',
#   'ModelHub': {'MetadataFilePath': 'data/huggingface/json/metadata/hf_metadata.json',
#    'MetadataObjectID': '123abhiALFLKFO/distilbert-base-uncased-finetuned-cola',
#    'ModelHubName': 'Hugging Face',
#    'ModelHubURL': 'https://huggingface.co/'},
#   'ModelName': '123abhiALFLKFO/distilbert-base-uncased-finetuned-cola',
#   'ModelOwner': '123abhiALFLKFO',
#   'ModelOwnerURL': 'https://huggingface.co/123abhiALFLKFO',
#   'ModelURL': 'https://huggingface.co/123abhiALFLKFO/distilbert-base-uncased-finetuned-cola',
#   'ModelArchitecture': 'distilbert',
#   'ModelTask': 'text-classification'},
#  {'id': 80,
#   'LatestGitCommitSHA': '19f6fd0fae058aae8467356f1ec80426f3f818a3',
#   'ModelHub': {'MetadataFilePath': 'data/huggingface/json/metadata/hf_metadata.json',
#    'MetadataObjectID': '123addfg/ar',
#    'ModelHubName': 'Hugging Face',
#    'ModelHubURL': 'https://huggingface.co/'},
#   'ModelName': '123addfg/ar',
#   'ModelOwner': '123addfg',
#   'ModelOwnerURL': 'https://huggingface.co/123addfg',
#   'ModelURL': 'https://huggingface.co/123addfg/ar'},
#  {'id': 81,
#   'LatestGitCommitSHA': '6881f4988ef8eaa1d33d9cd3ea39b748a0654ddc',
#   'ModelHub': {'MetadataFilePath': 'data/huggingface/json/metadata/hf_metadata.json',
#    'MetadataObjectID': '123www/test_model',
#    'ModelHubName': 'Hugging Face',
#    'ModelHubURL': 'https://huggingface.co/'},
#   'ModelName': '123www/test_model',
#   'ModelOwner': '123www',
#   'ModelOwnerURL': 'https://huggingface.co/123www',
#   'ModelURL': 'https://huggingface.co/123www/test_model',
#   'ModelArchitecture': 'wav2vec2'},
#  {'id': 82,
#   'LatestGitCommitSHA': '92c68c2dd3aeb0c9eb5fe79f57bd09e522a1cbbc',
#   'ModelHub': {'MetadataFilePath': 'data/huggingface/json/metadata/hf_metadata.json',
#    'MetadataObjectID': '13048909972/wav2vec2-common_voice-tr-demo',
#    'ModelHubName': 'Hugging Face',
#    'ModelHubURL': 'https://huggingface.co/'},
#   'ModelName': '13048909972/wav2vec2-common_voice-tr-demo',
#   'ModelOwner': '13048909972',
#   'ModelOwnerURL': 'https://huggingface.co/13048909972',
#   'ModelURL': 'https://huggingface.co/13048909972/wav2vec2-common_voice-tr-demo',
#   'ModelArchitecture': 'wav2vec2',
#   'ModelTask': 'automatic-speech-recognition'},
#  {'id': 83,
#   'LatestGitCommitSHA': '40c06d2135b1ce044d045f0ee54e88e24f81b7d6',
#   'ModelHub': {'MetadataFilePath': 'data/huggingface/json/metadata/hf_metadata.json',
#    'MetadataObjectID': '13048909972/wav2vec2-large-xls-r-300m-tr-colab',
#    'ModelHubName': 'Hugging Face',
#    'ModelHubURL': 'https://huggingface.co/'},
#   'ModelName': '13048909972/wav2vec2-large-xls-r-300m-tr-colab',
#   'ModelOwner': '13048909972',
#   'ModelOwnerURL': 'https://huggingface.co/13048909972',
#   'ModelURL': 'https://huggingface.co/13048909972/wav2vec2-large-xls-r-300m-tr-colab',
#   'ModelArchitecture': 'wav2vec2',
#   'ModelTask': 'automatic-speech-recognition'},
#  {'id': 84,
#   'LatestGitCommitSHA': '0a405d93927b1a0505838b961bcf645bfbc3e4c1',
#   'ModelHub': {'MetadataFilePath': 'data/huggingface/json/metadata/hf_metadata.json',
#    'MetadataObjectID': '13048909972/wav2vec2-large-xlsr-53_common_voice_20211210112254',
#    'ModelHubName': 'Hugging Face',
#    'ModelHubURL': 'https://huggingface.co/'},
#   'ModelName': '13048909972/wav2vec2-large-xlsr-53_common_voice_20211210112254',
#   'ModelOwner': '13048909972',
#   'ModelOwnerURL': 'https://huggingface.co/13048909972',
#   'ModelURL': 'https://huggingface.co/13048909972/wav2vec2-large-xlsr-53_common_voice_20211210112254'},
#  {'id': 85,
#   'LatestGitCommitSHA': '79e73cd04aaeec5f8c9b0aa5590926cdec954e0f',
#   'ModelHub': {'MetadataFilePath': 'data/huggingface/json/metadata/hf_metadata.json',
#    'MetadataObjectID': '13048909972/wav2vec2-large-xlsr-53_common_voice_20211211085606',
#    'ModelHubName': 'Hugging Face',
#    'ModelHubURL': 'https://huggingface.co/'},
#   'ModelName': '13048909972/wav2vec2-large-xlsr-53_common_voice_20211211085606',
#   'ModelOwner': '13048909972',
#   'ModelOwnerURL': 'https://huggingface.co/13048909972',
#   'ModelURL': 'https://huggingface.co/13048909972/wav2vec2-large-xlsr-53_common_voice_20211211085606',
#   'ModelArchitecture': 'wav2vec2',
#   'ModelTask': 'automatic-speech-recognition'},
#  {'id': 86,
#   'LatestGitCommitSHA': '1dd308da8f7962149fabc753b6a98c3e0e7a0418',
#   'ModelHub': {'MetadataFilePath': 'data/huggingface/json/metadata/hf_metadata.json',
#    'MetadataObjectID': '13306330378/huiqi_model',
#    'ModelHubName': 'Hugging Face',
#    'ModelHubURL': 'https://huggingface.co/'},
#   'ModelName': '13306330378/huiqi_model',
#   'ModelOwner': '13306330378',
#   'ModelOwnerURL': 'https://huggingface.co/13306330378',
#   'ModelURL': 'https://huggingface.co/13306330378/huiqi_model'},
#  {'id': 87,
#   'LatestGitCommitSHA': '769284ebaceeb7518f5f7f9fbc35ad94f8c59fe4',
#   'ModelHub': {'MetadataFilePath': 'data/huggingface/json/metadata/hf_metadata.json',
#    'MetadataObjectID': '13on/gpt2-wishes',
#    'ModelHubName': 'Hugging Face',
# ...
#   'ModelName': 'Atchuth/MBOT',
#   'ModelOwner': 'Atchuth',
#   'ModelOwnerURL': 'https://huggingface.co/Atchuth',
#   'ModelURL': 'https://huggingface.co/Atchuth/MBOT'},
#  {'id': 969,
#   'LatestGitCommitSHA': 'bd319170fe51ec55c5e8f693d08c5f80e0e91481',
#   'ModelHub': {'MetadataFilePath': 'data/huggingface/json/metadata/hf_metadata.json',
#    'MetadataObjectID': 'Ateeb/EmotionDetector',
#    'ModelHubName': 'Hugging Face',
#    'ModelHubURL': 'https://huggingface.co/'},
#   'ModelName': 'Ateeb/EmotionDetector',
#   'ModelOwner': 'Ateeb',
#   'ModelOwnerURL': 'https://huggingface.co/Ateeb',
#   'ModelURL': 'https://huggingface.co/Ateeb/EmotionDetector',
#   'ModelArchitecture': 'funnel',
#   'ModelTask': 'text-classification'},
#  {'id': 970,
#   'LatestGitCommitSHA': '03545aef305f7fcbaacf874ace6e0c8fd4be6e17',
#   'ModelHub': {'MetadataFilePath': 'data/huggingface/json/metadata/hf_metadata.json',
#    'MetadataObjectID': 'Ateeb/FullEmotionDetector',
#    'ModelHubName': 'Hugging Face',
#    'ModelHubURL': 'https://huggingface.co/'},
#   'ModelName': 'Ateeb/FullEmotionDetector',
#   'ModelOwner': 'Ateeb',
#   'ModelOwnerURL': 'https://huggingface.co/Ateeb',
#   'ModelURL': 'https://huggingface.co/Ateeb/FullEmotionDetector',
#   'ModelArchitecture': 'funnel',
#   'ModelTask': 'text-classification'},
#  {'id': 971,
#   'LatestGitCommitSHA': '00974c5ac9f8ba56d1368747c21d64ba5084b545',
#   'ModelHub': {'MetadataFilePath': 'data/huggingface/json/metadata/hf_metadata.json',
#    'MetadataObjectID': 'Ateeb/QA',
#    'ModelHubName': 'Hugging Face',
#    'ModelHubURL': 'https://huggingface.co/'},
#   'ModelName': 'Ateeb/QA',
#   'ModelOwner': 'Ateeb',
#   'ModelOwnerURL': 'https://huggingface.co/Ateeb',
#   'ModelURL': 'https://huggingface.co/Ateeb/QA',
#   'ModelArchitecture': 'distilbert',
#   'ModelTask': 'question-answering'},
#  {'id': 972,
#   'LatestGitCommitSHA': '4c80bc7e918707ebec6205c2c532e646f89bff7f',
#   'ModelHub': {'MetadataFilePath': 'data/huggingface/json/metadata/hf_metadata.json',
#    'MetadataObjectID': 'Ateeb/SquadQA',
#    'ModelHubName': 'Hugging Face',
#    'ModelHubURL': 'https://huggingface.co/'},
#   'ModelName': 'Ateeb/SquadQA',
#   'ModelOwner': 'Ateeb',
#   'ModelOwnerURL': 'https://huggingface.co/Ateeb',
#   'ModelURL': 'https://huggingface.co/Ateeb/SquadQA'},
#  {'id': 973,
#   'LatestGitCommitSHA': '9be0714e63cf17726845962539d81f017c5ee21a',
#   'ModelHub': {'MetadataFilePath': 'data/huggingface/json/metadata/hf_metadata.json',
#    'MetadataObjectID': 'Ateeb/asd',
#    'ModelHubName': 'Hugging Face',
#    'ModelHubURL': 'https://huggingface.co/'},
#   'ModelName': 'Ateeb/asd',
#   'ModelOwner': 'Ateeb',
#   'ModelOwnerURL': 'https://huggingface.co/Ateeb',
#   'ModelURL': 'https://huggingface.co/Ateeb/asd'},
#  {'id': 974,
#   'LatestGitCommitSHA': '092a20270dbe98e8472997f24b5874ec3915a932',
#   'ModelHub': {'MetadataFilePath': 'data/huggingface/json/metadata/hf_metadata.json',
#    'MetadataObjectID': 'Atiqah/Atiqah',
#    'ModelHubName': 'Hugging Face',
#    'ModelHubURL': 'https://huggingface.co/'},
#   'ModelName': 'Atiqah/Atiqah',
#   'ModelOwner': 'Atiqah',
#   'ModelOwnerURL': 'https://huggingface.co/Atiqah',
#   'ModelURL': 'https://huggingface.co/Atiqah/Atiqah'},
#  {'id': 975,
#   'LatestGitCommitSHA': '4b53c41764cd35f35773d3904b9e3f63cef8874c',
#   'ModelHub': {'MetadataFilePath': 'data/huggingface/json/metadata/hf_metadata.json',
#    'MetadataObjectID': 'Atlasky/Turkish-Negator',
#    'ModelHubName': 'Hugging Face',
#    'ModelHubURL': 'https://huggingface.co/'},
#   'ModelName': 'Atlasky/Turkish-Negator',
#   'ModelOwner': 'Atlasky',
#   'ModelOwnerURL': 'https://huggingface.co/Atlasky',
#   'ModelURL': 'https://huggingface.co/Atlasky/Turkish-Negator'},
#  {'id': 976,
#   'LatestGitCommitSHA': '242f7c05c00e5427a80cfc63ce4248a06028d4e1',
#   'ModelHub': {'MetadataFilePath': 'data/huggingface/json/metadata/hf_metadata.json',
#    'MetadataObjectID': 'Atlasky/turkish-negator-nn',
#    'ModelHubName': 'Hugging Face',
#    'ModelHubURL': 'https://huggingface.co/'},
#   'ModelName': 'Atlasky/turkish-negator-nn',
#   'ModelOwner': 'Atlasky',
#   'ModelOwnerURL': 'https://huggingface.co/Atlasky',
#   'ModelURL': 'https://huggingface.co/Atlasky/turkish-negator-nn'},
#  {'id': 977,
#   'LatestGitCommitSHA': 'da071a4ca0ca579c84f75dae64712d6ff4ade846',
#   'ModelHub': {'MetadataFilePath': 'data/huggingface/json/metadata/hf_metadata.json',
#    'MetadataObjectID': 'Augustab/distilbert-base-uncased-finetuned-cola',
#    'ModelHubName': 'Hugging Face',
#    'ModelHubURL': 'https://huggingface.co/'},
#   'ModelName': 'Augustab/distilbert-base-uncased-finetuned-cola',
#   'ModelOwner': 'Augustab',
#   'ModelOwnerURL': 'https://huggingface.co/Augustab',
#   'ModelURL': 'https://huggingface.co/Augustab/distilbert-base-uncased-finetuned-cola'},
#  {'id': 978,
#   'LatestGitCommitSHA': 'b956bb2d50e9623922fa950e5009b18bbcdd470a',
#   'ModelHub': {'MetadataFilePath': 'data/huggingface/json/metadata/hf_metadata.json',
#    'MetadataObjectID': 'Augustvember/WOKKAWOKKA',
#    'ModelHubName': 'Hugging Face',
#    'ModelHubURL': 'https://huggingface.co/'},
#   'ModelName': 'Augustvember/WOKKAWOKKA',
#   'ModelOwner': 'Augustvember',
#   'ModelOwnerURL': 'https://huggingface.co/Augustvember',
#   'ModelURL': 'https://huggingface.co/Augustvember/WOKKAWOKKA',
#   'ModelArchitecture': 'gpt2',
#   'ModelTask': 'conversational'},
#  {'id': 979,
#   'LatestGitCommitSHA': '8c80f36d3c2123bc9357ad4163dc25799dfac5cb',
#   'ModelHub': {'MetadataFilePath': 'data/huggingface/json/metadata/hf_metadata.json',
#    'MetadataObjectID': 'Augustvember/WokkaBot',
#    'ModelHubName': 'Hugging Face',
#    'ModelHubURL': 'https://huggingface.co/'},
#   'ModelName': 'Augustvember/WokkaBot',
#   'ModelOwner': 'Augustvember',
#   'ModelOwnerURL': 'https://huggingface.co/Augustvember',
#   'ModelURL': 'https://huggingface.co/Augustvember/WokkaBot'},
#  {'id': 980,
#   'LatestGitCommitSHA': '6832672585b10b6dbb83b604616926a5a77c41fa',
#   'ModelHub': {'MetadataFilePath': 'data/huggingface/json/metadata/hf_metadata.json',
#    'MetadataObjectID': 'Augustvember/WokkaBot2',
#    'ModelHubName': 'Hugging Face',
#    'ModelHubURL': 'https://huggingface.co/'},
#   'ModelName': 'Augustvember/WokkaBot2',
#   'ModelOwner': 'Augustvember',
#   'ModelOwnerURL': 'https://huggingface.co/Augustvember',
#   'ModelURL': 'https://huggingface.co/Augustvember/WokkaBot2'},
#  {'id': 981,
#   'LatestGitCommitSHA': '81a9213259fcdff68e23678717f8d2e5749627af',
#   'ModelHub': {'MetadataFilePath': 'data/huggingface/json/metadata/hf_metadata.json',
#    'MetadataObjectID': 'Augustvember/WokkaBot3',
#    'ModelHubName': 'Hugging Face',
#    'ModelHubURL': 'https://huggingface.co/'},
#   'ModelName': 'Augustvember/WokkaBot3',
#   'ModelOwner': 'Augustvember',
#   'ModelOwnerURL': 'https://huggingface.co/Augustvember',
#   'ModelURL': 'https://huggingface.co/Augustvember/WokkaBot3',
#   'ModelTask': 'conversational'},
#  {'id': 982,
#   'LatestGitCommitSHA': 'ef7af22bde75a049852486e5245c3561a2628a78',
#   'ModelHub': {'MetadataFilePath': 'data/huggingface/json/metadata/hf_metadata.json',
#    'MetadataObjectID': 'Augustvember/WokkaBot4',
#    'ModelHubName': 'Hugging Face',
#    'ModelHubURL': 'https://huggingface.co/'},
#   'ModelName': 'Augustvember/WokkaBot4',
#   'ModelOwner': 'Augustvember',
#   'ModelOwnerURL': 'https://huggingface.co/Augustvember',
#   'ModelURL': 'https://huggingface.co/Augustvember/WokkaBot4'},
#  {'id': 983,
#   'LatestGitCommitSHA': '640f5d7f59e9dc0b8aeeefd9a6ebb812c45681a2',
#   'ModelHub': {'MetadataFilePath': 'data/huggingface/json/metadata/hf_metadata.json',
#    'MetadataObjectID': 'Augustvember/WokkaBot5',
#    'ModelHubName': 'Hugging Face',
#    'ModelHubURL': 'https://huggingface.co/'},
#   'ModelName': 'Augustvember/WokkaBot5',
#   'ModelOwner': 'Augustvember',
#   'ModelOwnerURL': 'https://huggingface.co/Augustvember',
#   'ModelURL': 'https://huggingface.co/Augustvember/WokkaBot5'},
#  {'id': 984,
#   'LatestGitCommitSHA': 'ade6cff1dc8b6a115ef450d8f547165430936f28',
#   'ModelHub': {'MetadataFilePath': 'data/huggingface/json/metadata/hf_metadata.json',
#    'MetadataObjectID': 'Augustvember/WokkaBot6',
#    'ModelHubName': 'Hugging Face',
#    'ModelHubURL': 'https://huggingface.co/'},
#   'ModelName': 'Augustvember/WokkaBot6',
#   'ModelOwner': 'Augustvember',
#   'ModelOwnerURL': 'https://huggingface.co/Augustvember',
#   'ModelURL': 'https://huggingface.co/Augustvember/WokkaBot6'},
#  {'id': 985,
#   'LatestGitCommitSHA': '3b49811f53d241c7602c9eb9e5aa73acfaeeb901',
#   'ModelHub': {'MetadataFilePath': 'data/huggingface/json/metadata/hf_metadata.json',
#    'MetadataObjectID': 'Augustvember/WokkaBot7',
#    'ModelHubName': 'Hugging Face',
#    'ModelHubURL': 'https://huggingface.co/'},
#   'ModelName': 'Augustvember/WokkaBot7',
#   'ModelOwner': 'Augustvember',
#   'ModelOwnerURL': 'https://huggingface.co/Augustvember',
#   'ModelURL': 'https://huggingface.co/Augustvember/WokkaBot7'},
#  {'id': 986,
#   'LatestGitCommitSHA': '7397cf9bfdfc85adff480de9ac1c3cebe97d38ac',
#   'ModelHub': {'MetadataFilePath': 'data/huggingface/json/metadata/hf_metadata.json',
#    'MetadataObjectID': 'Augustvember/WokkaBot8',
#    'ModelHubName': 'Hugging Face',
#    'ModelHubURL': 'https://huggingface.co/'},
#   'ModelName': 'Augustvember/WokkaBot8',
#   'ModelOwner': 'Augustvember',
#   'ModelOwnerURL': 'https://huggingface.co/Augustvember',
#   'ModelURL': 'https://huggingface.co/Augustvember/WokkaBot8'},
#  {'id': 987,
#   'LatestGitCommitSHA': '4cc6d3b294934f935e59534bb857136bb23d2195',
#   'ModelHub': {'MetadataFilePath': 'data/huggingface/json/metadata/hf_metadata.json',
#    'MetadataObjectID': 'Augustvember/WokkaBot9',
#    'ModelHubName': 'Hugging Face',
#    'ModelHubURL': 'https://huggingface.co/'},
#   'ModelName': 'Augustvember/WokkaBot9',
#   'ModelOwner': 'Augustvember',
#   'ModelOwnerURL': 'https://huggingface.co/Augustvember',
#   'ModelURL': 'https://huggingface.co/Augustvember/WokkaBot9'},
#  {'id': 988,
#   'LatestGitCommitSHA': 'e2e3eece4ef5e5f3f0bb64d55610236752d8a244',
#   'ModelHub': {'MetadataFilePath': 'data/huggingface/json/metadata/hf_metadata.json',
#    'MetadataObjectID': 'Augustvember/WokkaBot99',
#    'ModelHubName': 'Hugging Face',
#    'ModelHubURL': 'https://huggingface.co/'},
#   'ModelName': 'Augustvember/WokkaBot99',
#   'ModelOwner': 'Augustvember',
#   'ModelOwnerURL': 'https://huggingface.co/Augustvember',
#   'ModelURL': 'https://huggingface.co/Augustvember/WokkaBot99'},
#  {'id': 989,
#   'LatestGitCommitSHA': '8b7afe107f594de18d98241721625a4f61e4a590',
#   'ModelHub': {'MetadataFilePath': 'data/huggingface/json/metadata/hf_metadata.json',
#    'MetadataObjectID': 'Augustvember/WokkaBotF',
#    'ModelHubName': 'Hugging Face',
#    'ModelHubURL': 'https://huggingface.co/'},
#   'ModelName': 'Augustvember/WokkaBotF',
#   'ModelOwner': 'Augustvember',
#   'ModelOwnerURL': 'https://huggingface.co/Augustvember',
#   'ModelURL': 'https://huggingface.co/Augustvember/WokkaBotF'},
#  {'id': 990,
#   'LatestGitCommitSHA': '2a840066c4ae4e6ea96ab9368541cb6a6cc9ec90',
#   'ModelHub': {'MetadataFilePath': 'data/huggingface/json/metadata/hf_metadata.json',
#    'MetadataObjectID': 'Augustvember/test',
#    'ModelHubName': 'Hugging Face',
#    'ModelHubURL': 'https://huggingface.co/'},
#   'ModelName': 'Augustvember/test',
#   'ModelOwner': 'Augustvember',
#   'ModelOwnerURL': 'https://huggingface.co/Augustvember',
#   'ModelURL': 'https://huggingface.co/Augustvember/test',
#   'ModelArchitecture': 'gpt2',
#   'ModelTask': 'conversational'},
#  {'id': 991,
#   'LatestGitCommitSHA': '09c5aab79ee2f25a856193bf47ed3eaec1dd46dd',
#   'ModelHub': {'MetadataFilePath': 'data/huggingface/json/metadata/hf_metadata.json',
#    'MetadataObjectID': 'Augustvember/wokka',
#    'ModelHubName': 'Hugging Face',
#    'ModelHubURL': 'https://huggingface.co/'},
#   'ModelName': 'Augustvember/wokka',
#   'ModelOwner': 'Augustvember',
#   'ModelOwnerURL': 'https://huggingface.co/Augustvember',
#   'ModelURL': 'https://huggingface.co/Augustvember/wokka',
#   'ModelArchitecture': 'gpt2',
#   'ModelTask': 'text-generation'},
#  {'id': 992,
#   'LatestGitCommitSHA': '171fd15c9a2dff4c496e723ecd736fbf35d36e08',
#   'ModelHub': {'MetadataFilePath': 'data/huggingface/json/metadata/hf_metadata.json',
#    'MetadataObjectID': 'Augustvember/wokka2',
#    'ModelHubName': 'Hugging Face',
#    'ModelHubURL': 'https://huggingface.co/'},
#   'ModelName': 'Augustvember/wokka2',
#   'ModelOwner': 'Augustvember',
#   'ModelOwnerURL': 'https://huggingface.co/Augustvember',
#   'ModelURL': 'https://huggingface.co/Augustvember/wokka2',
#   'ModelArchitecture': 'gpt2',
#   'ModelTask': 'conversational'},
#  {'id': 993,
#   'LatestGitCommitSHA': '7bb56763db94fd0fc685860049ef9898b646a737',
#   'ModelHub': {'MetadataFilePath': 'data/huggingface/json/metadata/hf_metadata.json',
#    'MetadataObjectID': 'Augustvember/wokka4',
#    'ModelHubName': 'Hugging Face',
#    'ModelHubURL': 'https://huggingface.co/'},
#   'ModelName': 'Augustvember/wokka4',
#   'ModelOwner': 'Augustvember',
#   'ModelOwnerURL': 'https://huggingface.co/Augustvember',
#   'ModelURL': 'https://huggingface.co/Augustvember/wokka4',
#   'ModelTask': 'conversational'},
#  {'id': 994,
#   'LatestGitCommitSHA': '9172900f98de94103f79dd3df8050b48d3bf5bbe',
#   'ModelHub': {'MetadataFilePath': 'data/huggingface/json/metadata/hf_metadata.json',
#    'MetadataObjectID': 'Augustvember/wokka5',
#    'ModelHubName': 'Hugging Face',
#    'ModelHubURL': 'https://huggingface.co/'},
#   'ModelName': 'Augustvember/wokka5',
#   'ModelOwner': 'Augustvember',
#   'ModelOwnerURL': 'https://huggingface.co/Augustvember',
#   'ModelURL': 'https://huggingface.co/Augustvember/wokka5',
#   'ModelArchitecture': 'gpt2',
#   'ModelTask': 'conversational'},
#  {'id': 995,
#   'LatestGitCommitSHA': 'c72656a6d8db3a879aed1eaed185a826e953908f',
#   'ModelHub': {'MetadataFilePath': 'data/huggingface/json/metadata/hf_metadata.json',
#    'MetadataObjectID': 'Augustvember/wokkabottest2',
#    'ModelHubName': 'Hugging Face',
#    'ModelHubURL': 'https://huggingface.co/'},
#   'ModelName': 'Augustvember/wokkabottest2',
#   'ModelOwner': 'Augustvember',
#   'ModelOwnerURL': 'https://huggingface.co/Augustvember',
#   'ModelURL': 'https://huggingface.co/Augustvember/wokkabottest2',
#   'ModelArchitecture': 'gpt2',
#   'ModelTask': 'conversational'},
#  {'id': 996,
#   'LatestGitCommitSHA': '3b642176d8b4437ee70e9ef6586c1083aa47668e',
#   'ModelHub': {'MetadataFilePath': 'data/huggingface/json/metadata/hf_metadata.json',
#    'MetadataObjectID': 'Augustvember/your-model-name',
#    'ModelHubName': 'Hugging Face',
#    'ModelHubURL': 'https://huggingface.co/'},
#   'ModelName': 'Augustvember/your-model-name',
#   'ModelOwner': 'Augustvember',
#   'ModelOwnerURL': 'https://huggingface.co/Augustvember',
#   'ModelURL': 'https://huggingface.co/Augustvember/your-model-name'},
#  {'id': 997,
#   'LatestGitCommitSHA': 'ccac5cdf2ad7a48d83607e69b47a1c4254ee0a97',
#   'ModelHub': {'MetadataFilePath': 'data/huggingface/json/metadata/hf_metadata.json',
#    'MetadataObjectID': 'Aurora/asdawd',
#    'ModelHubName': 'Hugging Face',
#    'ModelHubURL': 'https://huggingface.co/'},
#   'ModelName': 'Aurora/asdawd',
#   'ModelOwner': 'Aurora',
#   'ModelOwnerURL': 'https://huggingface.co/Aurora',
#   'ModelURL': 'https://huggingface.co/Aurora/asdawd'},
#  {'id': 998,
#   'LatestGitCommitSHA': 'e2bfcfd9941100d7440acf54e8afb495feb0af62',
#   'ModelHub': {'MetadataFilePath': 'data/huggingface/json/metadata/hf_metadata.json',
#    'MetadataObjectID': 'Aurora/community.afpglobal',
#    'ModelHubName': 'Hugging Face',
#    'ModelHubURL': 'https://huggingface.co/'},
#   'ModelName': 'Aurora/community.afpglobal',
#   'ModelOwner': 'Aurora',
#   'ModelOwnerURL': 'https://huggingface.co/Aurora',
#   'ModelURL': 'https://huggingface.co/Aurora/community.afpglobal'},
#  {'id': 999,
#   'LatestGitCommitSHA': '5d3d5f6a3f90a06bd468e0eb03dbf042a4bd55f1',
#   'ModelHub': {'MetadataFilePath': 'data/huggingface/json/metadata/hf_metadata.json',
#    'MetadataObjectID': 'AvatarXD/DialoGPT-medium-Blitzo',
#    'ModelHubName': 'Hugging Face',
#    'ModelHubURL': 'https://huggingface.co/'},
#   'ModelName': 'AvatarXD/DialoGPT-medium-Blitzo',
#   'ModelOwner': 'AvatarXD',
#   'ModelOwnerURL': 'https://huggingface.co/AvatarXD',
#   'ModelURL': 'https://huggingface.co/AvatarXD/DialoGPT-medium-Blitzo',
#   'ModelArchitecture': 'gpt2',
#   'ModelTask': 'conversational'},
#  ...]

# %%
for idx, metadata in enumerate(HF_metadata):
    logger.debug(metadata)
    model_name = metadata['ModelName']
    model_path = metadata['ModelHub']['MetadataObjectID']
    model_url = metadata['ModelURL']
    model_arch = metadata['ModelArchitecture']
    model_task = metadata['ModelTask']
    break
# Out:
# 2023-04-23 15:30:04.214 | DEBUG    | __main__:<module>:2 - {'id': 0, 'LatestGitCommitSHA': 'aeffd769076a5c4f83b2546aea99ca45a15a5da4', 'ModelHub': {'MetadataFilePath': 'data/huggingface/json/metadata/hf_metadata.json', 'MetadataObjectID': 'albert-base-v1', 'ModelHubName': 'Hugging Face', 'ModelHubURL': 'https://huggingface.co/'}, 'ModelName': 'albert-base-v1', 'ModelOwner': 'http://huggingface.co/', 'ModelOwnerURL': 'http://huggingface.co/', 'ModelURL': 'https://huggingface.co/albert-base-v1', 'ModelArchitecture': 'albert', 'ModelTask': 'fill-mask'}

# %%
repo_path = base_dir + '/' + model_path
repo_path
# Out:
# '/scratch/gilbreth/jiang784/PTMTorrent/huggingface/PTM-Torrent/ptm_torrent/huggingface/data/huggingface/repos/albert-base-v1'

# %%
# !ls repo_path
# Out:
# ls: cannot access repo_path: No such file or directory

# %%
import pandas as pd

# %%
# Initialize an empty list to store metadata dictionaries
metadata_list = []
metadata_list_noTask = []
metadata_list_noArch = []
metadata_list_nothing = []

for idx, metadata in enumerate(HF_metadata):
    # Extract metadata information
    try:
        metadata_dict = {
            'model_name': metadata['ModelName'],
            'model_path': metadata['ModelHub']['MetadataObjectID'],
            'model_url': metadata['ModelURL'],
            'model_architecture': metadata['ModelArchitecture'],
            'model_task': metadata['ModelTask'],
        }
        # Add the metadata dictionary to the list
        metadata_list.append(metadata_dict)
    except:
        try:
            metadata_dict = {
                'model_name': metadata['ModelName'],
                'model_path': metadata['ModelHub']['MetadataObjectID'],
                'model_url': metadata['ModelURL'],
                'model_architecture': metadata['ModelArchitecture'],
            }
            metadata_list_noTask.append(metadata_dict)
        except:
            try:
                metadata_dict = {
                    'model_name': metadata['ModelName'],
                    'model_path': metadata['ModelHub']['MetadataObjectID'],
                    'model_url': metadata['ModelURL'],
                    'model_task': metadata['ModelTask'],
                }
                metadata_list_noArch.append(metadata_dict)
            except:
                metadata_list_nothing.append((idx, metadata))

# Create a pandas DataFrame from the list of dictionaries
metadata_df = pd.DataFrame(metadata_list)
metadata_noTask_df = pd.DataFrame(metadata_list_noTask)
metadata_noArch_df = pd.DataFrame(metadata_list_noArch)


# Save the DataFrame to a CSV file
metadata_df.to_csv('/depot/davisjam/data/wenxin/CS577-NLP/project/metadata.csv', index=False)
metadata_noArch_df.to_csv('/depot/davisjam/data/wenxin/CS577-NLP/project/metadata_noArch.csv', index=False)
metadata_noTask_df.to_csv('/depot/davisjam/data/wenxin/CS577-NLP/project/metadata_noTask.csv', index=False)

# Save the metadata_nothing list
with open('/depot/davisjam/data/wenxin/CS577-NLP/project/metadata_nothing.txt', 'w') as file:
    for item in metadata_list_nothing:
        file.write(f"{item}\n")

# %%
len(metadata_df), len(metadata_noTask_df), len(metadata_noArch_df)
# Out:
# (61677, 3947, 12773)

# %%
mapping = {
    'feature-extraction': 'multimodal',
    'text-to-image': 'multimodal',
    'image-to-text': 'multimodal',
    'text-to-video': 'multimodal',
    'visual-question-answering': 'multimodal',
    'graph-machine-learning': 'multimodal',
    'depth-estimation': 'computer-vision',
    'image-classification': 'computer-vision',
    'object-detection': 'computer-vision',
    'image-segmentation': 'computer-vision',
    'image-to-image': 'computer-vision',
    'unconditional-image-generation': 'computer-vision',
    'video-classification': 'computer-vision',
    'zero-shot-image-classification': 'computer-vision',
    'text-classification': 'natural-language-processing',
    'token-classification': 'natural-language-processing',
    'table-question-answering': 'natural-language-processing',
    'question-answering': 'natural-language-processing',
    'zero-shot-classification': 'natural-language-processing',
    'translation': 'natural-language-processing',
    'summarization': 'natural-language-processing',
    'conversational': 'natural-language-processing',
    'text-generation': 'natural-language-processing',
    'text2text-generation': 'natural-language-processing',
    'fill-mask': 'natural-language-processing',
    'sentence-similarity': 'natural-language-processing',
    'multiple-choice': 'natural-language-processing',
    'document-question-answering': 'natural-language-processing',
    'text-to-speech': 'audio',
    'automatic-speech-recognition': 'audio',
    'audio-to-audio': 'audio',
    'audio-classification': 'audio',
    'voice-activity-detection': 'audio',
    'tabular-classification': 'tabular',
    'tabular-regression': 'tabular',
    'reinforcement-learning': 'reinforcement-learning',
    'robotics': 'reinforcement-learning',
    'null': None,
    'other': None,
}

# %%
def get_category(task):
    return mapping.get(task, "None")
for df in (metadata_df, metadata_noArch_df):
    # Add the new column based on the mapping
    df["model_category"] = df["model_task"].apply(get_category)

# %%
metadata_noArch_df
# Out:
#                                               model_name  \
# 0      AIDA-UPM/MSTSb_paraphrase-multilingual-MiniLM-...
# 1                                    AJ/rick-sanchez-bot
# 2                            AetherIT/DialoGPT-small-Hal
# 3                                        AkshaySg/langid
# 4                    AriakimTaiyo/DialoGPT-medium-Kumiko
# ...                                                  ...
# 12768    Kenemo/q-learning-frozenlake-v1-no-slippery-4x4
# 12769    Kenemo/q-learning-frozenlake-v1-no-slippery-8x8
# 12770                Kenemo/q-learning-frozenlake-v1-4x4
# 12771                                 iriscope/oscavatar
# 12772                Kenemo/q-learning-frozenlake-v1-8x8
#
#                                               model_path  \
# 0      AIDA-UPM/MSTSb_paraphrase-multilingual-MiniLM-...
# 1                                    AJ/rick-sanchez-bot
# 2                            AetherIT/DialoGPT-small-Hal
# 3                                        AkshaySg/langid
# 4                    AriakimTaiyo/DialoGPT-medium-Kumiko
# ...                                                  ...
# 12768    Kenemo/q-learning-frozenlake-v1-no-slippery-4x4
# 12769    Kenemo/q-learning-frozenlake-v1-no-slippery-8x8
# 12770                Kenemo/q-learning-frozenlake-v1-4x4
# 12771                                 iriscope/oscavatar
# 12772                Kenemo/q-learning-frozenlake-v1-8x8
#
#                                                model_url  \
# 0      https://huggingface.co/AIDA-UPM/MSTSb_paraphra...
# 1             https://huggingface.co/AJ/rick-sanchez-bot
# 2      https://huggingface.co/AetherIT/DialoGPT-small...
# 3                 https://huggingface.co/AkshaySg/langid
# 4      https://huggingface.co/AriakimTaiyo/DialoGPT-m...
# ...                                                  ...
# 12768  https://huggingface.co/Kenemo/q-learning-froze...
# 12769  https://huggingface.co/Kenemo/q-learning-froze...
# 12770  https://huggingface.co/Kenemo/q-learning-froze...
# 12771          https://huggingface.co/iriscope/oscavatar
# 12772  https://huggingface.co/Kenemo/q-learning-froze...
#
#                    model_task               model_category
# 0         sentence-similarity  natural-language-processing
# 1              conversational  natural-language-processing
# 2              conversational  natural-language-processing
# 3        audio-classification                        audio
# 4              conversational  natural-language-processing
# ...                       ...                          ...
# 12768  reinforcement-learning       reinforcement-learning
# 12769  reinforcement-learning       reinforcement-learning
# 12770  reinforcement-learning       reinforcement-learning
# 12771           text-to-image                   multimodal
# 12772  reinforcement-learning       reinforcement-learning
#
# [12773 rows x 5 columns]

# %%
metadata_df = metadata_df.drop("model_path", axis=1)
metadata_noArch_df = metadata_noArch_df.drop("model_path", axis=1)
metadata_noTask_df = metadata_noTask_df.drop("model_path", axis=1)

# %%
metadata_df.to_csv('/depot/davisjam/data/wenxin/CS577-NLP/project/metadata.csv', index=False)
metadata_noArch_df.to_csv('/depot/davisjam/data/wenxin/CS577-NLP/project/metadata_noArch.csv', index=False)
metadata_noTask_df.to_csv('/depot/davisjam/data/wenxin/CS577-NLP/project/metadata_noTask.csv', index=False)
